# %%
# 使用 BeautifulSoup、requests 來擷取 Wayback Machine 上的網頁內容並存成

## 簡介

這支程式的目的是協助使用者擷取特定年月、類別的文章列表，
透過 Wayback CDX API 與`requests`、`BeautifulSoup`取得文章 url、Wayback 快取的網址、文章 id，能夠初步查看總共有哪些文章。

為了加快速度，使用了多執行緒來加快程式運作。

```{tip}
以下皆是在Python3中執行。
在開始之前，建議先開一個虛擬環境，避免衝突。
```

     python3 -m venv .venv  # 建立虛擬環境 (資料夾名稱可自訂，一般用 .venv 或 venv)
    source .venv/bin/activate # 啟動虛擬環境 macOS / Linux
    .venv\Scripts\activate # Windows

```

```

````{note}
這支程式會使用 `requests`、`Beautiful Soup`這個套件與 Wayback Machine 做互動。
在開始之前，請先安裝：
    ```
        pip install requests BeautifulSoup
    ```
````

```python
import os
import time
import json
import zipfile
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed
from urllib.parse import urlparse
```

```python
# settings
INPUT_CSV = "example.csv"  # Input file with article URLs
URL_FIELD = "uri"
ID_FIELD = "id"
THREADS = 5
N_LIMIT = 10                    # None = all rows
OUTPUT_PREFIX = "output_"
SKIP_FILE_NAME = "skipped_urls.txt"
```

```python
# Utility functions
def _only_date(s: str) -> str:
    """
    Normalize different datetime formats into YYYY-MM-DD.
    Supported inputs include:
    - '20240207123456' (CDX timestamp)
    - '2024-02-07T12:34:56+08:00'
    - '2024-02-07 12:34:56'
    - '2024-02-07'
    Returns empty string if parsing fails.
    """
    if not s:
        return ""
    s = s.strip()
    if s.isdigit() and len(s) == 14:  # CDX format
        try:
            return datetime.strptime(s, "%Y%m%d%H%M%S").strftime("%Y-%m-%d")
        except Exception:
            pass
    for fmt in ("%Y-%m-%dT%H:%M:%S%z",
                "%Y-%m-%dT%H:%M:%S",
                "%Y-%m-%d %H:%M:%S",
                "%Y-%m-%d"):
        try:
            dt = datetime.strptime(s.replace("Z", "+0000"), fmt)
            return dt.strftime("%Y-%m-%d")
        except Exception:
            continue
    if len(s) >= 10 and s[4] == "-" and s[7] == "-":
        return s[:10]
    return ""


def _first_path_segment(raw_url: str) -> str:
    """
    Return the first path segment of a URL.
    Example: /local/20200729/... -> 'local'
    """
    try:
        p = urlparse(raw_url)
        parts = [seg for seg in p.path.split("/") if seg]
        return parts[0] if parts else ""
    except Exception:
        return ""


def _ensure_dir(path: str):
    os.makedirs(path, exist_ok=True)
```

```python
# Wayback Scraper
class WaybackScraper:
    def __init__(self, img_root_dir):
        self.session = requests.Session()
        self.session.headers.update({'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'})
        self.img_root_dir = img_root_dir
        _ensure_dir(self.img_root_dir)

    def get_latest_snapshot(self, url):
        """
        Query the CDX API for the latest snapshot of a given URL.
        Returns timestamp, original URL, and constructed Wayback URL.
        """
        api = "https://web.archive.org/cdx/search/cdx"
        params = {
            'url': url,
            'output': 'json',
            'filter': 'statuscode:200',
            'sort': 'reverse',
            'limit': 1
        }
        try:
            r = self.session.get(api, params=params, timeout=20)
            r.raise_for_status()
            data = r.json()
            if len(data) > 1:
                row = data[1]
                return {
                    'timestamp': row[1],
                    'original_url': row[2],
                    'wayback_url': f"https://web.archive.org/web/{row[1]}/{row[2]}"
                }
        except Exception as e:
            print(f"[CDX error] {url} → {e}, params={params}")
        return None

    def _extract_published_date(self, soup, wayback_ts: str) -> str:
        """
        Try to extract a published date from <meta property='article:published_time'>
        or <time datetime>. Fall back to Wayback timestamp if none are found.
        """
        meta = soup.find("meta", attrs={"property": "article:published_time"})
        if meta and meta.get("content"):
            d = _only_date(meta.get("content"))
            if d:
                return d
        t = soup.find("time")
        if t:
            d = _only_date(t.get("datetime") or t.get_text(strip=True))
            if d:
                return d
        return _only_date(wayback_ts)

    def scrape_article(self, wayback_url: str, raw_url: str, wayback_ts: str):
        """
        Parse a Wayback snapshot page to extract:
        - title
        - body text (concatenated <p> tags)
        - publication date
        - category (from URL path)
        - image URLs (first = cover, rest = others)
        """
        try:
            resp = self.session.get(wayback_url, timeout=20)
            resp.raise_for_status()
            soup = BeautifulSoup(resp.content, 'html.parser')

            # Title
            title_tag = soup.find("h1") or soup.find("title")
            title = title_tag.get_text(strip=True) if title_tag else ""

            # Body text
            bodies = "\n".join(
                p.get_text().strip()
                for p in soup.find_all("p")
                if p.get_text().strip()
            )

            # Dates
            firstcreated = self._extract_published_date(soup, wayback_ts)
            contentcreated = firstcreated
            versioncreated = _only_date(wayback_ts)

            # Collect images
            all_img_urls = []
            for img in soup.find_all("img"):
                src = img.get("src")
                if not src:
                    continue
                if src.startswith("//"):
                    src = "https:" + src
                elif not src.startswith("http"):
                    src = f"https://web.archive.org{src}"
                if src not in all_img_urls:
                    all_img_urls.append(src)

            subject = _first_path_segment(raw_url)

            return {
                "title": title,
                "bodies": bodies,
                "firstcreated": firstcreated,
                "versioncreated": versioncreated,
                "contentcreated": contentcreated,
                "subject": subject,
                "all_img_urls": all_img_urls
            }
        except Exception as e:
            print(f"[Parse error] {wayback_url} (raw={raw_url}) → {e}")
            return None

    def download_images(self, urls, item_id):
        """
        Download all images for an article.
        Saved to images/{item_id}/img/
        Filenames: {item_id}_cover_1.jpg (first), {item_id}_other_2.jpg (rest).
        Returns a list of filenames aligned with input URLs.
        """
        saved_files = []
        item_img_dir = os.path.join(self.img_root_dir, item_id, "img")
        _ensure_dir(item_img_dir)

        for i, url in enumerate(urls, 1):
            try:
                ext = os.path.splitext(url)[1].split("?")[0].lower()
                if ext not in ['.jpg', '.jpeg', '.png', '.gif', '.webp']:
                    ext = '.jpg'
                label = "cover" if i == 1 else "other"
                fname = f"{item_id}_{label}_{i}{ext}"
                fpath = os.path.join(item_img_dir, fname)

                r = self.session.get(url, timeout=20)
                if r.status_code == 200:
                    with open(fpath, "wb") as f:
                        f.write(r.content)
                    saved_files.append(fname)
                else:
                    print(f"[Download failed {r.status_code}] {url}")
                    saved_files.append("")
            except Exception as e:
                print(f"[Download error] {url} → {e}")
                saved_files.append("")
        return saved_files
```
# Out:
# 開始時間： 2025-08-20 11:40:50
# 共讀取 50 個 URL，開始處理…
# [1] v https://www.appledaily.com.tw/local/20220101/23YFPLCSYZCZPANVI4E2LTW5L4/
# [2] v https://www.appledaily.com.tw/local/20220101/4C4Q3YRHTZGGBN2YAHLJH4CSQI/
# [3] v https://www.appledaily.com.tw/local/20220101/C4AZKGYVYZDVTPWZ7RPWARUHDY/
# [4] v https://www.appledaily.com.tw/local/20220101/C5GNIZT4DNA4DAFUVA5NHKJYDI/
# [5] v https://www.appledaily.com.tw/local/20220101/DUS6LUBV2FEHBHZ5R47BG6YCCY/
# [6] v https://www.appledaily.com.tw/local/20220101/E4KZSUGK2JFJ7ODIJ6MZKAGZBE/
# [7] v https://www.appledaily.com.tw/local/20220101/HZEOOEE2DRE3XP3YZ4QFRL7UXI/
# [8] v https://www.appledaily.com.tw/local/20220101/J34SI2C7PFA7VEIBA3BLINE4IU/
# [9] v https://www.appledaily.com.tw/local/20220101/K54XGASEKBBEVCFVQ35NP6CWOE/
# [10] v https://www.appledaily.com.tw/local/20220101/KB7OQRBQ75CIDCHR7KVMLAFGBM/
# [11] v https://www.appledaily.com.tw/local/20220101/LDYGE3C3QZA6HF6ZIGH64EWNTA/
# [12] v https://www.appledaily.com.tw/local/20220101/M535PM4OKVDQHMICHJQZIMD5WA/
# [13] v https://www.appledaily.com.tw/local/20220101/MBTKRW5L2NEB3D4LNLK4HWK3RU/
# [14] v https://www.appledaily.com.tw/local/20220101/N5QZTAKJBBBKZA7EPSKMCWAY2A/
# [15] v https://www.appledaily.com.tw/local/20220101/O24ZJITVMNBBDIZLV5KGHGX5FM/
# [16] v https://www.appledaily.com.tw/local/20220101/OD5KVIYKGNHLDFYPW7EJTRBGPI/
# [17] v https://www.appledaily.com.tw/local/20220101/OMVXBBBZEBCFXO62KUVQMPQJKE/
# [18] v https://www.appledaily.com.tw/local/20220101/PMJ2RVEC35BGDE5N5GR4L3YHBQ/
# [19] v https://www.appledaily.com.tw/local/20220101/Q3RD2ZBGXVEWFCRDOIUFZMD2PU/
# [20] v https://www.appledaily.com.tw/local/20220101/Q7XH6YGAINFFBH6SB66LUNLLKI/
# [21] v https://www.appledaily.com.tw/local/20220101/R3JCANESKZF6FGJZ3ZMTKDYPKA/
# [22] v https://www.appledaily.com.tw/local/20220101/RJKBMUW6IVCZ7NWHQ5BUEYQYRM/
# [23] v https://www.appledaily.com.tw/local/20220101/RMLOA4737NFFVMHMHQBECE26SU/
# [24] v https://www.appledaily.com.tw/local/20220101/S5AMHWR5VVEHXONQSFD62KN5AQ/
# [25] v https://www.appledaily.com.tw/local/20220101/TUAX4GAG2BD4LMA3RV47Y653WU/
# [26] v https://www.appledaily.com.tw/local/20220101/TYKCCUT2XFH5BKNMMMMHJNZUIY/
# [27] v https://www.appledaily.com.tw/local/20220101/UXVRNCWYO5DAFE33WCHQ6IF3BQ/
# [28] v https://www.appledaily.com.tw/local/20220101/UYVUAJIUZVBH3CN4BLIF7YOJEU/
# [29] v https://www.appledaily.com.tw/local/20220101/VCDHRVGHIZGXNEP5W3YR74GNKU/
# [30] v https://www.appledaily.com.tw/local/20220101/VCPT2IQJXJFKVEM5PPQY6PFHMU/
# [31] v https://www.appledaily.com.tw/local/20220101/WD4VETWEHZDXXHZ6IPPKLCJQHQ/
# [32] v https://www.appledaily.com.tw/local/20220101/XA3ANJACNJF2DCDDRAKAKQYJNA/
# [33] v https://www.appledaily.com.tw/local/20220101/Y4RXVI2E3BCBZKYWN4XEBAHJRQ/
# [34] v https://www.appledaily.com.tw/local/20220101/ZACSNGAVAVAANOZHTMVTXEHYSI/
# [35] v https://www.appledaily.com.tw/local/20220101/ZLHGMQBHNZF2ZL5AVPGALRJSWI/
# [36] v https://www.appledaily.com.tw/local/20220101/ZPF5UQ4OMJC73BNGTBUVLEZXQY/
# [37] v https://www.appledaily.com.tw/local/20220102/2I4EE6YADZE4JII4X6ISR5TVYE/
# [38] v https://www.appledaily.com.tw/local/20220102/3M62LY75IFENNFX4ABCOWNC4GA/
# [39] v https://www.appledaily.com.tw/local/20220102/5P7ZPIFIONBEZJMCQSIJNLYBAE/
# [40] v https://www.appledaily.com.tw/local/20220102/7NUKQAVIB5BR5PUEGTPUNUT6DY/
# [41] v https://www.appledaily.com.tw/local/20220102/7SHU5WPFHRGBPIKBUVOWW5MBEE/
# [42] v https://www.appledaily.com.tw/local/20220102/AEXPNREESBGQLFQBA7OBEVAQMM/
# [43] v https://www.appledaily.com.tw/local/20220102/B2XNCC5W3NDRFPVYDUN7KB44FI/
# [44] v https://www.appledaily.com.tw/local/20220102/B3G2XTI5IBG7DHW5ZMKSLJRGVU/
# [45] v https://www.appledaily.com.tw/local/20220102/BBH2XIMG3RBQPHXNRKYEZ4N3CE/
# [46] v https://www.appledaily.com.tw/local/20220102/BBNBYQIH25DBLNXALEMA54SBJQ/
# [47] v https://www.appledaily.com.tw/local/20220102/BGCB3EEKHRCBXEQLGFWNXABO6U/
# [48] v https://www.appledaily.com.tw/local/20220102/C533EDQCYFCQ5LRTNGJU4IQD3A/
# [49] v https://www.appledaily.com.tw/local/20220102/CDHQZGMFTZF65G25YHW5PMB2TE/
# [50] v https://www.appledaily.com.tw/local/20220102/D2EHT3XKZBCVNBMVSMXJ4R372A/
# [v] 已輸出 json / csv
# 結束時間： 2025-08-20 11:43:39
# 總耗時：169.06 秒

# %%
#多執行緒
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup
import time
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed

class WaybackScraper:
    def __init__(self):
        self.session = requests.Session()
        self.session.headers.update({
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
        })
    
    def get_latest_snapshot(self, url):
        params = {
            'url': url,
            'output': 'json',
            'filter': 'statuscode:200',
            'sort': 'reverse',
            'limit': 1
        }
        try:
            r = self.session.get("https://web.archive.org/cdx/search/cdx", params=params, timeout=20)
            r.raise_for_status()
            data = r.json()
            if len(data) > 1:
                row = data[1]
                return {
                    'timestamp': row[1],
                    'original_url': row[2],
                    'wayback_url': f"https://web.archive.org/web/{row[1]}/{row[2]}"
                }
        except Exception as e:
            print(f"[CDX錯誤] {url} → {e}")
        return None

    def scrape_webpage_content(self, wayback_url):
        try:
            resp = self.session.get(wayback_url, timeout=10)
            resp.raise_for_status()
            soup = BeautifulSoup(resp.content, 'html.parser')
            content = "\n".join([p.get_text().strip() for p in soup.find_all('p') if p.get_text().strip()])
            return content
        except Exception as e:
            print(f"[爬取錯誤] {wayback_url} → {e}")
            return None

    def format_timestamp(self, ts):
        try:
            return datetime.strptime(ts, "%Y%m%d%H%M%S").strftime("%Y-%m-%d %H:%M:%S")
        except:
            return ts

def process_one_url(row):
    """一個網址的處理流程（for thread pool）"""
    raw_url = row[url_field]
    snap = scraper.get_latest_snapshot(raw_url)
    if not snap:
        return None

    content = scraper.scrape_webpage_content(snap['wayback_url'])
    if content:
        return {
            id_field: row[id_field],
            url_field: raw_url,
            "bodies": content,
            "timestamp": snap['timestamp'],
            "formatted_date": scraper.format_timestamp(snap['timestamp']),
            "wayback_url": snap['wayback_url']
        }
    return None


# === 主程式 ===
if __name__ == "__main__":
    import time
    from datetime import datetime
    
    import logging
    logging.basicConfig(
        filename='wayback.log',
        filemode='a',
        level=logging.INFO,
        format='%(asctime)s [%(levelname)s] %(message)s',
    )
    
    start_time = time.time()
    start_dt = datetime.now()
    print("開始時間：", start_dt.strftime("%Y-%m-%d %H:%M:%S"))

    csv_path = "only_in_b.csv"
    url_field = "uri"
    id_field = "id"
    N_LIMIT = None
    THREADS = 5   # 要開幾條執行緒

    df = pd.read_csv(csv_path)
    if N_LIMIT:
        df = df.head(N_LIMIT)

    scraper = WaybackScraper()
    results = []

    with ThreadPoolExecutor(max_workers=THREADS) as executor:
        future_to_row = {executor.submit(process_one_url, row): row for _, row in df.iterrows()}

        for i, future in enumerate(as_completed(future_to_row), 1):
            data = future.result()
            if data:
                results.append(data)
                print(f"[{i}] v {data[url_field]}")
            else:
                print(f"[{i}] x 失敗")

    # === 輸出 JSON & CSV ===
    if results:
        with open("wayback_threads.json", "w", encoding="utf-8") as f:
            json.dump(results, f, ensure_ascii=False, indent=2)
        print("v JSON 已輸出：wayback_threads.json")

        pd.DataFrame(results).to_csv("wayback_threads.csv", index=False, encoding="utf-8-sig")
        print("v CSV 已輸出：wayback_threads.csv")
    else:
        print("全部失敗 ")

    end_time = time.time()
    end_dt = datetime.now()
    print("結束時間：", end_dt.strftime("%Y-%m-%d %H:%M:%S"))
    print(f"總耗時：{end_time - start_time:.2f} 秒")
    logging.info(f"結束時間：{end_dt.strftime('%Y-%m-%d %H:%M:%S')}")
    logging.info(f"總耗時：{end_time - start_time:.2f} 秒")
    logging.info("== 結束 ==\n")
# Out:
# 開始時間： 2025-08-20 12:04:29
# [1] v https://www.appledaily.com.tw/local/20220101/C5GNIZT4DNA4DAFUVA5NHKJYDI/
# [2] v https://www.appledaily.com.tw/local/20220101/4C4Q3YRHTZGGBN2YAHLJH4CSQI/
# [3] v https://www.appledaily.com.tw/local/20220101/C4AZKGYVYZDVTPWZ7RPWARUHDY/
# [4] v https://www.appledaily.com.tw/local/20220101/E4KZSUGK2JFJ7ODIJ6MZKAGZBE/
# [5] v https://www.appledaily.com.tw/local/20220101/HZEOOEE2DRE3XP3YZ4QFRL7UXI/
# [6] v https://www.appledaily.com.tw/local/20220101/J34SI2C7PFA7VEIBA3BLINE4IU/
# [7] v https://www.appledaily.com.tw/local/20220101/K54XGASEKBBEVCFVQ35NP6CWOE/
# [8] v https://www.appledaily.com.tw/local/20220101/KB7OQRBQ75CIDCHR7KVMLAFGBM/
# [9] v https://www.appledaily.com.tw/local/20220101/MBTKRW5L2NEB3D4LNLK4HWK3RU/
# [10] v https://www.appledaily.com.tw/local/20220101/N5QZTAKJBBBKZA7EPSKMCWAY2A/
# [11] v https://www.appledaily.com.tw/local/20220101/23YFPLCSYZCZPANVI4E2LTW5L4/
# [12] v https://www.appledaily.com.tw/local/20220101/O24ZJITVMNBBDIZLV5KGHGX5FM/
# [13] v https://www.appledaily.com.tw/local/20220101/M535PM4OKVDQHMICHJQZIMD5WA/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220101/DUS6LUBV2FEHBHZ5R47BG6YCCY/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [14] x 失敗
# [15] v https://www.appledaily.com.tw/local/20220101/PMJ2RVEC35BGDE5N5GR4L3YHBQ/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220101/LDYGE3C3QZA6HF6ZIGH64EWNTA/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [16] x 失敗
# [17] v https://www.appledaily.com.tw/local/20220101/OD5KVIYKGNHLDFYPW7EJTRBGPI/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220101/OMVXBBBZEBCFXO62KUVQMPQJKE/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [18] x 失敗
# [19] v https://www.appledaily.com.tw/local/20220101/Q7XH6YGAINFFBH6SB66LUNLLKI/
# [20] v https://www.appledaily.com.tw/local/20220101/Q3RD2ZBGXVEWFCRDOIUFZMD2PU/
# [21] v https://www.appledaily.com.tw/local/20220101/RMLOA4737NFFVMHMHQBECE26SU/
# [22] v https://www.appledaily.com.tw/local/20220101/R3JCANESKZF6FGJZ3ZMTKDYPKA/
# [23] v https://www.appledaily.com.tw/local/20220101/UXVRNCWYO5DAFE33WCHQ6IF3BQ/
# [24] v https://www.appledaily.com.tw/local/20220101/RJKBMUW6IVCZ7NWHQ5BUEYQYRM/
# [25] v https://www.appledaily.com.tw/local/20220101/TUAX4GAG2BD4LMA3RV47Y653WU/
# [26] v https://www.appledaily.com.tw/local/20220101/VCPT2IQJXJFKVEM5PPQY6PFHMU/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220101/S5AMHWR5VVEHXONQSFD62KN5AQ/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [27] x 失敗
# [28] v https://www.appledaily.com.tw/local/20220101/TYKCCUT2XFH5BKNMMMMHJNZUIY/
# [29] v https://www.appledaily.com.tw/local/20220101/VCDHRVGHIZGXNEP5W3YR74GNKU/
# [30] v https://www.appledaily.com.tw/local/20220101/ZACSNGAVAVAANOZHTMVTXEHYSI/
# [31] v https://www.appledaily.com.tw/local/20220101/ZLHGMQBHNZF2ZL5AVPGALRJSWI/
# [32] v https://www.appledaily.com.tw/local/20220101/UYVUAJIUZVBH3CN4BLIF7YOJEU/
# [33] v https://www.appledaily.com.tw/local/20220101/WD4VETWEHZDXXHZ6IPPKLCJQHQ/
# [34] v https://www.appledaily.com.tw/local/20220102/3M62LY75IFENNFX4ABCOWNC4GA/
# [35] v https://www.appledaily.com.tw/local/20220102/5P7ZPIFIONBEZJMCQSIJNLYBAE/
# [36] v https://www.appledaily.com.tw/local/20220102/2I4EE6YADZE4JII4X6ISR5TVYE/
# [37] v https://www.appledaily.com.tw/local/20220102/7NUKQAVIB5BR5PUEGTPUNUT6DY/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220101/XA3ANJACNJF2DCDDRAKAKQYJNA/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [38] x 失敗
# [39] v https://www.appledaily.com.tw/local/20220101/Y4RXVI2E3BCBZKYWN4XEBAHJRQ/
# [40] x 失敗
# [CDX錯誤] https://www.appledaily.com.tw/local/20220101/ZPF5UQ4OMJC73BNGTBUVLEZXQY/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [41] x 失敗
# [42] v https://www.appledaily.com.tw/local/20220102/B2XNCC5W3NDRFPVYDUN7KB44FI/
# [43] v https://www.appledaily.com.tw/local/20220102/BBH2XIMG3RBQPHXNRKYEZ4N3CE/
# [44] v https://www.appledaily.com.tw/local/20220102/B3G2XTI5IBG7DHW5ZMKSLJRGVU/
# [45] v https://www.appledaily.com.tw/local/20220102/AEXPNREESBGQLFQBA7OBEVAQMM/
# [46] v https://www.appledaily.com.tw/local/20220102/CDHQZGMFTZF65G25YHW5PMB2TE/
# [47] v https://www.appledaily.com.tw/local/20220102/C533EDQCYFCQ5LRTNGJU4IQD3A/
# [48] v https://www.appledaily.com.tw/local/20220102/BGCB3EEKHRCBXEQLGFWNXABO6U/
# [49] v https://www.appledaily.com.tw/local/20220102/GSGUYYYJGFA5TPYPONL7CM5JLY/
# [50] v https://www.appledaily.com.tw/local/20220102/BBNBYQIH25DBLNXALEMA54SBJQ/
# [51] v https://www.appledaily.com.tw/local/20220102/DP2DHKNWYBFWHOUBTZ67AGKYXI/
# [52] v https://www.appledaily.com.tw/local/20220102/D2EHT3XKZBCVNBMVSMXJ4R372A/
# [53] v https://www.appledaily.com.tw/local/20220102/JIW3J4HAEJGU5N23UKQFTBYU7I/
# [54] v https://www.appledaily.com.tw/local/20220102/NP46GEDTBZANZMGSZHI5BIDE54/
# [55] v https://www.appledaily.com.tw/local/20220102/P22PV33XQVBNHJRYAPG24XU3W4/
# [56] v https://www.appledaily.com.tw/local/20220102/NSUHONLZVJB3PCG6GEAPIWHFAQ/
# [57] v https://www.appledaily.com.tw/local/20220102/QK6YUUZOGZDF3FBT6DAM4G3CDQ/
# [58] v https://www.appledaily.com.tw/local/20220102/PAZOAY6LKZHGVKNG5JX7X5UNUE/
# [59] v https://www.appledaily.com.tw/local/20220102/RZL5PJP4DJAITPRF6RNLFDHMTM/
# [60] v https://www.appledaily.com.tw/local/20220102/SBEHCWJUQZFHNEY537K2EBRYPE/
# [61] v https://www.appledaily.com.tw/local/20220102/MHIP3IN6QJCYXI7W3Q6X4NC7PU/
# [62] v https://www.appledaily.com.tw/local/20220102/MLO62BMSGZARXMUISFEDRKHABI/
# [63] v https://www.appledaily.com.tw/local/20220102/SVFMFAY2GZEY5PYDUDCBSV6HTA/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220102/H5RA7S4LPNHBRAELL2ZSHQ4ZEE/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [64] x 失敗
# [65] v https://www.appledaily.com.tw/local/20220102/V75LDFTSRZCMZOU2OYIXFGEYVY/
# [66] v https://www.appledaily.com.tw/local/20220102/TZSJAJQA7NDFDAEYNTGDVFO6HM/
# [67] v https://www.appledaily.com.tw/local/20220102/VAJOGQDRIBDR7BYWQBZPPOI35A/
# [68] v https://www.appledaily.com.tw/local/20220102/TZN6HSJHYNE6BDJJGCJUYH5PLM/
# [69] v https://www.appledaily.com.tw/local/20220103/3HSG5YTFTVAMBOKILX54PKHTTY/
# [70] v https://www.appledaily.com.tw/local/20220103/2KSCP2LWLJEETGFVUS2NLIDSAE/
# [71] v https://www.appledaily.com.tw/local/20220103/2ZRSYUYPWZF53PLV4X23RJSWFE/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220102/TWUP4L3RJJGNHKDV64LPEZIS4E/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [72] x 失敗
# [73] v https://www.appledaily.com.tw/local/20220103/6AFGZ5KP4RD5BGXPQ7RDDUSQTE/
# [74] v https://www.appledaily.com.tw/local/20220103/6QOU52UUFZBOXIAXWDFIIBBQJQ/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220102/Z2HLEKK6GFF6FOP2HTGVB6V3YA/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [75] x 失敗
# [76] v https://www.appledaily.com.tw/local/20220103/6U72YRSSLZBWLFFURUKRSKIMPE/
# [77] v https://www.appledaily.com.tw/local/20220103/66GC3MGWQRECFMLCWXT7TBWEFM/
# [78] v https://www.appledaily.com.tw/local/20220103/5OQR57GYXJDNHNAXMNHV6TGHRQ/
# [79] v https://www.appledaily.com.tw/local/20220103/7DSWZBK7VZFG5NTWJKGYIUHXXI/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220103/47Q27RNP4VH6DK7JS52S2UZQSY/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [80] x 失敗
# [81] v https://www.appledaily.com.tw/local/20220103/DG6DLCTV3RC3DBQVXXRE7FGVOA/
# [82] v https://www.appledaily.com.tw/local/20220103/AUODWLXQQZHRJFARY35OCOAYOE/
# [83] v https://www.appledaily.com.tw/local/20220103/CBB3OJLPAJHXFDMGOGZUFSSXHM/
# [84] x 失敗
# [85] v https://www.appledaily.com.tw/local/20220103/DTDWL6ZFERA23AFQFZRYZMWUGM/
# [86] v https://www.appledaily.com.tw/local/20220103/FH7SLXI5BBAPPAHBOWP5NBGYKI/
# [87] v https://www.appledaily.com.tw/local/20220103/FHB6W47SEVHYZII5DPCUJGOW2I/
# [88] v https://www.appledaily.com.tw/local/20220103/FJFMIF3FYNCIXB3G5UYZVAOR7E/
# [89] v https://www.appledaily.com.tw/local/20220103/ET53UC6HYZGWLEV2WMTGYZY4VU/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220103/AGMWRL544ZHCHNK23RNP5QTOJQ/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [90] x 失敗
# [91] v https://www.appledaily.com.tw/local/20220103/FYVMCWML4RFV5J5C7GP76ZCYUM/
# [92] v https://www.appledaily.com.tw/local/20220103/GHYG7B67TNH5HLKEYSCLNJPMMY/
# [93] v https://www.appledaily.com.tw/local/20220103/FAQBUG4WPFHGNDUXW5X6FJFAGU/
# [94] v https://www.appledaily.com.tw/local/20220103/H53NEFUMN5GYXM3WC5PLNRABTA/
# [95] v https://www.appledaily.com.tw/local/20220103/IJYQKVT2XRETFPMIDVVUBNL7ZQ/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220103/GOTHC6MBCNBZZOX5BQDJYARXII/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [96] x 失敗
# [97] v https://www.appledaily.com.tw/local/20220103/IZHNCRYTYBC3ZMOKJFMVJGL7WE/
# [98] v https://www.appledaily.com.tw/local/20220103/JRKR2PGG5ZHSTNFJCLOEP3WWTI/
# [99] v https://www.appledaily.com.tw/local/20220103/KX32F3LK45DE5B7LWKBXYRB7S4/
# [100] v https://www.appledaily.com.tw/local/20220103/J36ZECS2SBHA5O3E2X2XNFQLW4/
# [101] v https://www.appledaily.com.tw/local/20220103/JBLBFIPHLVD5NMDKLSLWWGKTSI/
# [102] v https://www.appledaily.com.tw/local/20220103/LPN4IUAMRJHNRPPAYSALXDVGNU/
# [103] v https://www.appledaily.com.tw/local/20220103/PPDRBHJ2FJAO5OEMOKTXMMPKQM/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220103/IZSAJQ3BWZEAPIGCG4ANFDVVTI/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [104] x 失敗
# [105] v https://www.appledaily.com.tw/local/20220103/LPTP5EJMEJBOZGI6WP5ORW7E3U/
# [106] v https://www.appledaily.com.tw/local/20220103/LWOLMRKW3BGWTGTWSBOL5RYX7A/
# [107] v https://www.appledaily.com.tw/local/20220103/QZROJV7OWFHEVMNNIYHG3SY34U/
# [108] v https://www.appledaily.com.tw/local/20220103/RHZVJULO2ZDPXBG6NURTWUTDFQ/
# [109] v https://www.appledaily.com.tw/local/20220103/SJTI3CEXVBFJDGOJLSUEBJYDOM/
# [110] v https://www.appledaily.com.tw/local/20220103/T47TSKWG55D2FLWK4MGIXJY5M4/
# [111] v https://www.appledaily.com.tw/local/20220103/QW2ZWQGK3JBBPFQOSCLHWEKK5M/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220103/QI4YIQPHRZHWBACPQ4IB5QS27I/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [112] x 失敗
# [113] v https://www.appledaily.com.tw/local/20220103/TAH36O4MABH7LCKQEQOGV5OLXY/
# [114] v https://www.appledaily.com.tw/local/20220103/THAGDCNKEVEZRB3VKMNRZCKMPE/
# [115] x 失敗
# [116] x 失敗
# [117] v https://www.appledaily.com.tw/local/20220103/W7GKTYF4BNDE7EEH3DTQBVMNFM/
# [118] v https://www.appledaily.com.tw/local/20220103/VCVDOMCKGND3DCDJBHUMC3DGQQ/
# [119] v https://www.appledaily.com.tw/local/20220103/VS76LB5WVBGQ5MUW7K6L7Q2UMQ/
# [120] v https://www.appledaily.com.tw/local/20220103/WPZJGNFEGNH47ESKIGMZVLIFCY/
# [121] v https://www.appledaily.com.tw/local/20220103/XQZXZWDOCJDJTIYO6UQMX2XGTI/
# [122] v https://www.appledaily.com.tw/local/20220103/WWJCDE73NZANPBS5G4ZIDL2BBQ/
# [123] v https://www.appledaily.com.tw/local/20220103/Y3LBL7PTKBEILIQ42HHCDIJ2PQ/
# [124] v https://www.appledaily.com.tw/local/20220103/YDOCCZRHHNF4BMXVGCERF57REQ/
# [125] v https://www.appledaily.com.tw/local/20220103/YKPKMWH32JH5DOKUYNANDBIZYA/
# [126] x 失敗
# [127] v https://www.appledaily.com.tw/local/20220103/ZCUXSLKPGNFOPF2ELSEGIDTFHA/
# [128] v https://www.appledaily.com.tw/local/20220104/2CI7EPXKYRGDFFU3QI3FFP3BRQ/
# [129] v https://www.appledaily.com.tw/local/20220104/2PZUOXPCSZA2BGZVWN6JJLDVSU/
# [130] v https://www.appledaily.com.tw/local/20220103/ZMJZURZFJVF4NLOMCIMXCZKNOQ/
# [131] v https://www.appledaily.com.tw/local/20220103/ZHYTTIFVWBHGFI4CLQ66YKNHLQ/
# [爬取錯誤] https://web.archive.org/web/20220913143401/https://www.appledaily.com.tw/local/20220104/5QWOO7W2CJAVHFUPK5RJWEL254/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=10)
# [132] x 失敗
# [CDX錯誤] https://www.appledaily.com.tw/local/20220104/3LICO57UY5AURECQZCUAFTAT5I/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [133] x 失敗
# [134] v https://www.appledaily.com.tw/local/20220104/5GYGS4QT4VHQ7KRN2CIXTYUKJU/
# [135] v https://www.appledaily.com.tw/local/20220104/5R56QEK4JJAC3ECC3IPK3IA33I/
# [136] v https://www.appledaily.com.tw/local/20220104/4YSPNABLPVGYRNEARHW5E6BON4/
# [137] v https://www.appledaily.com.tw/local/20220104/6QHREHHHDZBPDF4YMGV6PXBX3I/
# [138] v https://www.appledaily.com.tw/local/20220104/C2K25WMIVRATFIWNR3LLYJBM5Q/
# [139] v https://www.appledaily.com.tw/local/20220104/AWLMYJSKNZHPXNX6F5FOFPNR34/
# [140] v https://www.appledaily.com.tw/local/20220104/CNEX4XJJDRHPLKZKSZ5WAVT7ZU/
# [141] v https://www.appledaily.com.tw/local/20220104/CATL6SZ43NHEDLRTG2MIJ2Y6LE/
# [142] v https://www.appledaily.com.tw/local/20220104/76J3H7EAAFGVHO7QPHCATZNAWA/
# [143] v https://www.appledaily.com.tw/local/20220104/7D3FAAXSAVAFNEVNWJSBBJXARI/
# [144] v https://www.appledaily.com.tw/local/20220104/FQRYEB7IIBHN5G7T3HVJWL3MDI/
# [145] v https://www.appledaily.com.tw/local/20220104/CZ7RU2G2S5CBBF5BA3OCN3N6LE/
# [146] v https://www.appledaily.com.tw/local/20220104/DGSJSKIVABHFJGUS33ZIO7OVZM/
# [147] v https://www.appledaily.com.tw/local/20220104/GA3XNV66NNF67JYZFFYKFUCSCQ/
# [148] v https://www.appledaily.com.tw/local/20220104/FXHM5Z7G4VEIBI6KKSTY6KGTZE/
# [149] v https://www.appledaily.com.tw/local/20220104/FCD3ASWAWREWFHIQB6NJTCUNK4/
# [150] v https://www.appledaily.com.tw/local/20220104/GWRLHX44KVGJDLRM4B7PEOXXZY/
# [151] v https://www.appledaily.com.tw/local/20220104/GXNEPGBXGVCRRBQAHESERYOP2A/
# [152] v https://www.appledaily.com.tw/local/20220104/GXUKTMWOBVADNGPIXAY2YP3EEA/
# [153] v https://www.appledaily.com.tw/local/20220104/HFVX2RQHFJHDBPD4JQCXLOVWAY/
# [154] v https://www.appledaily.com.tw/local/20220104/HWICBX3A6VGKJOFTWRLUOC7ZJI/
# [155] v https://www.appledaily.com.tw/local/20220104/LMDOCLIGOBHCNOT3X2FGWCSZ2A/
# [156] v https://www.appledaily.com.tw/local/20220104/GJUXBOS4PJGFPIIEV3VDPSHOB4/
# [157] v https://www.appledaily.com.tw/local/20220104/H6GXYPLVHVCIVK6NV5NEDQBRJY/
# [158] v https://www.appledaily.com.tw/local/20220104/OITAT4C4HNCUJCM3QZLKVLLFXM/
# [159] v https://www.appledaily.com.tw/local/20220104/NII55T5FEBAMPFFKWYYUZ7WT5Y/
# [160] v https://www.appledaily.com.tw/local/20220104/MM2MSISBORCEXPPYIKBNHEMOU4/
# [161] v https://www.appledaily.com.tw/local/20220104/JZCTESHHPRCYTA4N6A3VGTPLYY/
# [162] v https://www.appledaily.com.tw/local/20220104/JFDS27N3EFEXBNKBUCMJAKWEA4/
# [163] v https://www.appledaily.com.tw/local/20220104/PRIJFORU2JADHGO7S6BIOBVYJM/
# [164] v https://www.appledaily.com.tw/local/20220104/PWQPUMVPWJDYTBOZCTW7KX77YM/
# [165] v https://www.appledaily.com.tw/local/20220104/SBADFTGTTNGSVLSG5PMB5GRIYQ/
# [166] v https://www.appledaily.com.tw/local/20220104/TDBGNGTH75DQXIKRMN7WVYDH2A/
# [167] v https://www.appledaily.com.tw/local/20220104/UGBIVY4K2JCY7HQK4O26G4LARY/
# [168] v https://www.appledaily.com.tw/local/20220104/ORGZQAOJWREX5FYWACX7JFEJQI/
# [169] v https://www.appledaily.com.tw/local/20220104/UKCJ6FODFJECHPKICTSBDMXNLQ/
# [170] v https://www.appledaily.com.tw/local/20220104/URTAUXPAQVCFZHCQD2GICO3DJY/
# [171] v https://www.appledaily.com.tw/local/20220104/VBMZYN33OBDSHIBDZLQA47CB64/
# [172] v https://www.appledaily.com.tw/local/20220104/P7WZ6OBXPJDW3BKK3IBQWLREOQ/
# [173] v https://www.appledaily.com.tw/local/20220104/W5BYOWRJRNDGLHEEGFXDZNILRA/
# [174] v https://www.appledaily.com.tw/local/20220104/WBE2NNFRBJE4RFXN6BNRBXB7PY/
# [175] v https://www.appledaily.com.tw/local/20220104/W2PK4VCHKVB3POPHOD7DYVMJ2Y/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220104/PODJAXOVPZF6JPLXUY7LPTXXRM/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [176] x 失敗
# [177] v https://www.appledaily.com.tw/local/20220104/WO6CEWFBYVC2HFOIYZWOKDG5RQ/
# [178] v https://www.appledaily.com.tw/local/20220104/WQOF4M4NWBHR7PA2IEDEMJE6F4/
# [179] v https://www.appledaily.com.tw/local/20220104/VFDUGTLDPFBDNKYWC7VIWX3GMY/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220104/USDS6STWDBDAFEYYKGKAJ5GM6M/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [180] x 失敗
# [181] v https://www.appledaily.com.tw/local/20220104/WV7AKUSXHZHTPNQOQ2A5RZYZFA/
# [182] x 失敗
# [183] v https://www.appledaily.com.tw/local/20220104/ZZDLPCSFURBCPFSRYSQFP6XEDU/
# [184] v https://www.appledaily.com.tw/local/20220104/YJMOCR34HBDKRLR3KT33FTTCUU/
# [185] v https://www.appledaily.com.tw/local/20220105/2LJFOS2GXZHDDHGP3WE64AVBQI/
# [186] v https://www.appledaily.com.tw/local/20220105/2XEACXIB6NHLFHKMLZYXEYWKMA/
# [187] v https://www.appledaily.com.tw/local/20220104/WMSP5462DJAELOQQUN53CNQZKU/
# [188] v https://www.appledaily.com.tw/local/20220104/XP3TYWXWERF3PNAZPHIJFBYFNI/
# [189] v https://www.appledaily.com.tw/local/20220105/3JPIEQCWS5DSRI5MD4CVPAADMY/
# [190] v https://www.appledaily.com.tw/local/20220105/2HBCD6PVUFBYHC6LQ4HRCUNHXQ/
# [191] v https://www.appledaily.com.tw/local/20220105/5HCGWXZDGNDKHNOGMQZWS6BOBU/
# [192] v https://www.appledaily.com.tw/local/20220105/3L4OAUIRIRDIRDUWWXNQJKY7AE/
# [193] v https://www.appledaily.com.tw/local/20220105/5Z4JZUUOUZAJDM54BR5JYQIQIY/
# [194] v https://www.appledaily.com.tw/local/20220105/5CNVWOGC5JEODC56AWI5U7IUDA/
# [195] v https://www.appledaily.com.tw/local/20220105/7FD4QA2ZXRCGJPYY6HECA6ATRM/
# [196] v https://www.appledaily.com.tw/local/20220105/62K4XB2RO5C5NM6UXGTXLF2TVA/
# [197] v https://www.appledaily.com.tw/local/20220105/5XDSJXHC3RCQLBHX4RA6MJ6VTE/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220105/5QX7HXQ4S5DAJG46VY2JKBMAHU/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [198] x 失敗
# [199] v https://www.appledaily.com.tw/local/20220105/7YQ6JTNUFBA3TAINTKCI5UVX4Q/
# [200] v https://www.appledaily.com.tw/local/20220105/ACU7XGIEFNEIFAYSWZD7U3SSDA/
# [201] v https://www.appledaily.com.tw/local/20220105/B6I4VJD6RRDFDPUIULQNAJ7EXE/
# [202] v https://www.appledaily.com.tw/local/20220105/BAITETTYYFCUVLU72UDWIRXBEY/
# [203] v https://www.appledaily.com.tw/local/20220105/A22XUGG7QBG33NS5BIV6MFOQ7M/
# [204] v https://www.appledaily.com.tw/local/20220105/ADVZNEEX7FANDALIKFLNWJLRAY/
# [205] v https://www.appledaily.com.tw/local/20220105/BIC7USRE3NGIZFI62NTNDTTH3I/
# [206] v https://www.appledaily.com.tw/local/20220105/CBRXRPHD7JARZM3HN5UXKZX7YQ/
# [207] v https://www.appledaily.com.tw/local/20220105/DSUVZXAIYFC6VHDFJBERWF7OME/
# [208] v https://www.appledaily.com.tw/local/20220105/F4WWTV353RGCHCW6O47AX2BHZY/
# [209] v https://www.appledaily.com.tw/local/20220105/FYY5VNQUKBH4NB5SHSY5ADOZTU/
# [210] v https://www.appledaily.com.tw/local/20220105/GIL6WJE5BBECZHASUMOOT5KKSQ/
# [211] v https://www.appledaily.com.tw/local/20220105/FUAY2LFNTRDFHLFUZO2XW7U3LY/
# [212] v https://www.appledaily.com.tw/local/20220105/HDSTVRMYPFAAJH6YK7F6S37TZ4/
# [213] v https://www.appledaily.com.tw/local/20220105/EJ2ATFSP6BD2NKM5ATKMUQMROI/
# [214] v https://www.appledaily.com.tw/local/20220105/HLCNPJ2MOBA47P2TCU7RSTZF4M/
# [215] v https://www.appledaily.com.tw/local/20220105/F6GKUKDKGJHHVEWQPD6CB4VWP4/
# [216] v https://www.appledaily.com.tw/local/20220105/J2FTNJ5J5VFWNF7ULKEH6SHMVA/
# [217] v https://www.appledaily.com.tw/local/20220105/JC2CJCTJXND7LBFMY6VUHHMJII/
# [218] v https://www.appledaily.com.tw/local/20220105/JNCUQK4FBJDC7LXJWSIUADFRNY/
# [219] v https://www.appledaily.com.tw/local/20220105/G5ATBL6YVZFMVDI6XQ2WH2MYDI/
# [220] v https://www.appledaily.com.tw/local/20220105/K4Y66EUZTRD2PFYACMPLNML2WI/
# [221] v https://www.appledaily.com.tw/local/20220105/LKUOWRFVQFBN7BQDQB7JZ3GHYM/
# [222] v https://www.appledaily.com.tw/local/20220105/LG7P6QTO5ZDSFDDUTTIJ6VYU7M/
# [223] v https://www.appledaily.com.tw/local/20220105/M6FAQCR4ZFHWDOIAYKZNTLDQIA/
# [224] v https://www.appledaily.com.tw/local/20220105/IHM7QUYZERAKNA4OEPTHMHJZ6M/
# [225] v https://www.appledaily.com.tw/local/20220105/N5ZI4OTQBVBPVOVIBS63TLE5IU/
# [226] v https://www.appledaily.com.tw/local/20220105/NGML6LDCLZGY7DJGE3JMGGWSAQ/
# [227] x 失敗
# [228] v https://www.appledaily.com.tw/local/20220105/OFILPMD3DVHVXPIHSZN3U6AGCE/
# [229] v https://www.appledaily.com.tw/local/20220105/KGKKE6XNLJDD3MFQ5YEBZKKREQ/
# [230] v https://www.appledaily.com.tw/local/20220105/M53ISUWQTFFLDEHVP6ZN2SDQOA/
# [231] v https://www.appledaily.com.tw/local/20220105/P4DXKNK4D5FZXBUIXFTTIITZ74/
# [232] v https://www.appledaily.com.tw/local/20220105/PY6KACRTA5HAJOS7Z4JOJ6OFMY/
# [233] v https://www.appledaily.com.tw/local/20220105/OJE2PNCWQJB2FNOWKO3GH64BNM/
# [234] v https://www.appledaily.com.tw/local/20220105/PDYZITUL3BGX5MREWSNTMF7GFQ/
# [235] v https://www.appledaily.com.tw/local/20220105/Q3IFKHZWUBFXHDUOJMDH5ZKWV4/
# [236] v https://www.appledaily.com.tw/local/20220105/QWK5TVCG4ZA3XHR2SKJRPRJRYI/
# [237] v https://www.appledaily.com.tw/local/20220105/S537RJ6LS5FTTGTUIUKD5BJTXI/
# [238] v https://www.appledaily.com.tw/local/20220105/QWM6GWGPFZFGFLIPHP4UWLXEXQ/
# [239] v https://www.appledaily.com.tw/local/20220105/SVNDDIFG3ZGSLKMWP5HWOFAQGQ/
# [240] v https://www.appledaily.com.tw/local/20220105/SWKAAHPS6ZFHZBCDDYCUI3LTTE/
# [241] v https://www.appledaily.com.tw/local/20220105/TCIRO2NLKZEBHGK3TCLNOIPU4Q/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220105/MQDXJLYT2VBLFHW6ZLHBVRJ6EY/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [242] x 失敗
# [243] v https://www.appledaily.com.tw/local/20220105/TULD6I3D65E37A774JSWVLZQF4/
# [244] v https://www.appledaily.com.tw/local/20220105/UHVILMCUWNG4XFTCROSUIWUBL4/
# [245] v https://www.appledaily.com.tw/local/20220105/UDGCRHKBTBAYPCYAJC2WNJYO6A/
# [246] v https://www.appledaily.com.tw/local/20220105/U7EXQWUUBNFLLKNITGLRD2HYNA/
# [247] v https://www.appledaily.com.tw/local/20220105/X6J5TC4MHBCJ5AYP343MB4VU7Q/
# [248] v https://www.appledaily.com.tw/local/20220105/VGAVQYG4VRE2RAJ2LG4Z3YBWY4/
# [249] v https://www.appledaily.com.tw/local/20220105/X7UIYV745BB2HA5EYJMCEGWI6Q/
# [250] v https://www.appledaily.com.tw/local/20220105/XHKNZQKL3BF5VJ4XN5UDKKGBYE/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220105/RNBUIBO6SRCKFGLGHNWVVDV7DA/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [251] x 失敗
# [252] v https://www.appledaily.com.tw/local/20220105/SV2CORGTFVDF7P7OMJN5DDPJDE/
# [253] v https://www.appledaily.com.tw/local/20220106/2SGOQJULXRA4PLSGYK36BUK5ZA/
# [254] v https://www.appledaily.com.tw/local/20220105/X7FBHWLQHBBXPC5HPTFFKPT2PI/
# [255] v https://www.appledaily.com.tw/local/20220106/2ZEIJS5IUVGMNJYKEEPSCPJZSU/
# [256] v https://www.appledaily.com.tw/local/20220106/3MPBZ2BQSRD2RCU32YK7CPZOCU/
# [257] v https://www.appledaily.com.tw/local/20220105/ZKEE54ZVOFHEDDM3YWW5Q74NXM/
# [258] v https://www.appledaily.com.tw/local/20220105/ZIDWNGOY7JAYVMRHWUQKKLI4U4/
# [259] v https://www.appledaily.com.tw/local/20220106/4M3ZPYK5KREAJOSQY5GMJYW4UE/
# [260] v https://www.appledaily.com.tw/local/20220106/7ICA7CKDBVEXDCOIU3FMWXBBXA/
# [261] v https://www.appledaily.com.tw/local/20220106/7X2QT2GD7JEGXECRITSTYFXGNM/
# [262] v https://www.appledaily.com.tw/local/20220106/7Y4SPOANIVEMTFAJR4GRI3KN4Y/
# [263] v https://www.appledaily.com.tw/local/20220106/A4T2JIXPZVHMXBIFDAQVTM66WA/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220105/ZIUC2PETTJG7FFY7PZATKNVS2E/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [264] x 失敗
# [265] v https://www.appledaily.com.tw/local/20220106/CDSAA6FVXJG47LIGANRG6IZC34/
# [266] v https://www.appledaily.com.tw/local/20220106/5TDEISJPJNEDTBHMTRGCYBJMAY/
# [267] v https://www.appledaily.com.tw/local/20220106/6A4E3KPTIZDXRA3R7VFJAQFHMQ/
# [268] v https://www.appledaily.com.tw/local/20220106/EPIQDO2LOJERRBFXOOVBTUKEPI/
# [269] v https://www.appledaily.com.tw/local/20220106/E6B2S7NYJVBBPJDKOK5CFBEBAM/
# [270] v https://www.appledaily.com.tw/local/20220106/DG6FJFXJYFA37L3BYOL73RSSAQ/
# [271] v https://www.appledaily.com.tw/local/20220106/6ZMIML2NSFDM5M73GKITE4O4KU/
# [272] v https://www.appledaily.com.tw/local/20220106/D2URPBH6HBDINMSCJTHFH3QLQE/
# [273] v https://www.appledaily.com.tw/local/20220106/FPNSZZBBMFHZTJVVUM63SPJFVM/
# [274] v https://www.appledaily.com.tw/local/20220106/FHFNVKXU7ZBTXFMXISBPZDX224/
# [275] v https://www.appledaily.com.tw/local/20220106/FYONZIUUEZGMVGHFYASWJ7V2KI/
# [276] v https://www.appledaily.com.tw/local/20220106/FE3VGEQMARCVZCAC5IDJI5RHMI/
# [277] v https://www.appledaily.com.tw/local/20220106/JGHF3TTMY5GRTG7T6AU6XPW34A/
# [278] v https://www.appledaily.com.tw/local/20220106/KXKXUDDVYFF2LIEJZOVI6DWVEQ/
# [279] v https://www.appledaily.com.tw/local/20220106/ML6W4CKUDFAXTMPVQ6NWFY4P4M/
# [280] v https://www.appledaily.com.tw/local/20220106/MFVSOFOYUNF67L5CCBKDRTQPKA/
# [281] v https://www.appledaily.com.tw/local/20220106/MWZAFNJKOZEZZL7MRI4V75I2R4/
# [282] v https://www.appledaily.com.tw/local/20220106/NBBZJRD47BAURMQNRK6VUMAYXM/
# [283] v https://www.appledaily.com.tw/local/20220106/MXLJC7E4VJHZ7IJTYJN3V5CJRI/
# [284] v https://www.appledaily.com.tw/local/20220106/OCCC672AZBDV5D42VA2VE7JR5M/
# [285] v https://www.appledaily.com.tw/local/20220106/PQJUJJDMEJDS7IIQR7PBCMGCMI/
# [286] v https://www.appledaily.com.tw/local/20220106/POFLZTEFLBDBNIZHMOZDN3GAZY/
# [287] v https://www.appledaily.com.tw/local/20220106/OVG5E7AISJB7ZLIQIZ4INWSAWA/
# [288] v https://www.appledaily.com.tw/local/20220106/G72NVQTYNZAK5LY5TS5YOCV6IQ/
# [289] v https://www.appledaily.com.tw/local/20220106/PSLLC6M2H5E73DSLALZHR26N7Y/
# [290] v https://www.appledaily.com.tw/local/20220106/RJ2LXYXFN5EALG2IRBSUZB5O2U/
# [291] v https://www.appledaily.com.tw/local/20220106/GN2HHL4SENEMPKKLWNNHVVQDJM/
# [292] v https://www.appledaily.com.tw/local/20220106/R4AW5MNHXNFDBBS32Z2MW5QNBE/
# [293] v https://www.appledaily.com.tw/local/20220106/VCBYPQ537NCPRGWYQTM56A2XTY/
# [294] v https://www.appledaily.com.tw/local/20220106/VWPT5RIYFRCNFAKE4IWGSCDW5A/
# [295] v https://www.appledaily.com.tw/local/20220106/X53D6IXDKFG57A3B24EYNHNHFM/
# [296] v https://www.appledaily.com.tw/local/20220106/WGPUW6LFS5HYHOZDL5XXTCSW3Y/
# [297] v https://www.appledaily.com.tw/local/20220106/V2VLZPHIVRDFTC562NSLQCHRKQ/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220106/U66AIUGTAVERRFZRIX3YIF4HLY/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [298] x 失敗
# [299] v https://www.appledaily.com.tw/local/20220106/ZXYN4T263JANHAK26QESAQE22A/
# [300] v https://www.appledaily.com.tw/local/20220106/W5TPCD62MRH47JR7WS2BM44L3M/
# [301] v https://www.appledaily.com.tw/local/20220107/2IUMEMJ54ZA2NCFZ4YE7XOJLRE/
# [302] v https://www.appledaily.com.tw/local/20220107/2HRTFPYNJRCB7FHVRTIV5QHGAE/
# [303] v https://www.appledaily.com.tw/local/20220107/2XN3FBSXBBGG7IX2ICIUVL623I/
# [304] v https://www.appledaily.com.tw/local/20220106/YKOJB2OTENB3RHVEAECZK2ZFRA/
# [305] v https://www.appledaily.com.tw/local/20220107/3I6Q5IMY45EZJJWAPUTJ2P5LCY/
# [306] v https://www.appledaily.com.tw/local/20220106/XBIIBRXVOJF5NCDX4LQIHBKPDQ/
# [307] v https://www.appledaily.com.tw/local/20220106/YZDEGEWQ4NCIJHERJZQNHAGDIM/
# [308] v https://www.appledaily.com.tw/local/20220107/5C3G2JTD6FEY3LW3NPZ7COPDDY/
# [309] v https://www.appledaily.com.tw/local/20220107/3F2WNWLJS5EHBEYFMHBRHAFHPI/
# [310] v https://www.appledaily.com.tw/local/20220107/A73BERL22ZFKBCYYESXHNLSOBY/
# [311] v https://www.appledaily.com.tw/local/20220107/AAMMLODOOBEBNGN7TD6GRYHRSQ/
# [312] v https://www.appledaily.com.tw/local/20220107/BC5FVVQBVRHK7B2D5Y5W6P45CE/
# [313] v https://www.appledaily.com.tw/local/20220107/BQBPYDSDLJF7PPVEBDWZZCQRRE/
# [314] v https://www.appledaily.com.tw/local/20220107/3U4LBBWH6RHWDCHHENPUSPKQCE/
# [315] v https://www.appledaily.com.tw/local/20220107/3PSJCSGNCVF6BGBN52WACFQ2EE/
# [316] v https://www.appledaily.com.tw/local/20220107/543LXPTOW5C45HXBSLF23GZAIM/
# [317] v https://www.appledaily.com.tw/local/20220107/A6B32KGNFBBGFITP74WH4QWP2A/
# [318] v https://www.appledaily.com.tw/local/20220107/CAX5OMDANNCJDCL27JDBWN5W3M/
# [319] v https://www.appledaily.com.tw/local/20220107/COVKBRDEY5GGZJSMTXCBUL2YPQ/
# [320] v https://www.appledaily.com.tw/local/20220107/CK2XITBMVREVRLBEWI7V3M265A/
# [321] v https://www.appledaily.com.tw/local/20220107/CPPAB74FQBCJFLKSEKFLOIFZ6Q/
# [322] v https://www.appledaily.com.tw/local/20220107/FVZJAX6UWFG5PMSLAIWQE2CHHY/
# [323] v https://www.appledaily.com.tw/local/20220107/CS4HEF5TXFEWJKKXT5YB45HSKA/
# [324] v https://www.appledaily.com.tw/local/20220107/DEYBZTZIYRHGFF3ZIVQP2X3PEQ/
# [325] v https://www.appledaily.com.tw/local/20220107/G2Q4ZDY7UVAALIVW6QDLUBDC5Q/
# [326] v https://www.appledaily.com.tw/local/20220107/GAD2DKJUEFBZHLGRICDGZMGJMQ/
# [327] v https://www.appledaily.com.tw/local/20220107/EMM3ZIM3LVADJL6PK6WBPNMHRU/
# [328] v https://www.appledaily.com.tw/local/20220107/HM4J4EKQMFD3ZCBRX4MSUWEXCI/
# [329] v https://www.appledaily.com.tw/local/20220107/KNSVXE3GJBAYZD44BAOWMLQ76I/
# [330] v https://www.appledaily.com.tw/local/20220107/LGU42XPN3REWHMROOCLBBEM42Q/
# [331] v https://www.appledaily.com.tw/local/20220107/M34VYOKTCVBGVK3UWALY3ECIBQ/
# [332] v https://www.appledaily.com.tw/local/20220107/HV54KPJGANH2DMWXRU7UE2MXYU/
# [333] v https://www.appledaily.com.tw/local/20220107/HXTTV56TEZG5RD42HPNLYKIC5M/
# [334] v https://www.appledaily.com.tw/local/20220107/JP2OZFL4LNAORDNQTKVUSAKTC4/
# [335] v https://www.appledaily.com.tw/local/20220107/NGGFDNIIEZFD5FO3R3KRIQWDC4/
# [336] v https://www.appledaily.com.tw/local/20220107/MHPSWCM5WFDL5J3Q33S2KULORI/
# [337] v https://www.appledaily.com.tw/local/20220107/O77OEPUK6FFU5DNXC7TAD4FG4M/
# [338] v https://www.appledaily.com.tw/local/20220107/MHF2LZJ7SRAV7IZHE7DHHXF7II/
# [339] v https://www.appledaily.com.tw/local/20220107/LUODISR5IRA4NHSEZ2TQH6ILJQ/
# [340] v https://www.appledaily.com.tw/local/20220107/MFCBB2XSZVAEBNUJFTCP4T6MXU/
# [341] v https://www.appledaily.com.tw/local/20220107/O3QI3XQKKVABHI634AG5QUVXM4/
# [342] v https://www.appledaily.com.tw/local/20220107/QA3SO42J4JG67IPUWWLZ7EMXTM/
# [343] v https://www.appledaily.com.tw/local/20220107/OJMTMTWIFZFSBBOJHRSCWSXPXE/
# [344] v https://www.appledaily.com.tw/local/20220107/QIV3THN7MRGI5CBG6XHXIFGFOU/
# [345] v https://www.appledaily.com.tw/local/20220107/RML4LYKPGZEYJJIULGY4RNZDAY/
# [346] v https://www.appledaily.com.tw/local/20220107/RHHWRVWDQBDYPKW3EJADRAU2O4/
# [347] x 失敗
# [348] v https://www.appledaily.com.tw/local/20220107/PLSL27CUUZB4BF526VHZ3TYKTQ/
# [349] v https://www.appledaily.com.tw/local/20220107/SR3F3O3D6JDLDEIAEIVMCXTB6A/
# [350] v https://www.appledaily.com.tw/local/20220107/OZJJZZ25AVBMTOYNS6FNQYLANU/
# [351] v https://www.appledaily.com.tw/local/20220107/UMCPN2OVT5DADI6KPUG4S6AM3M/
# [352] v https://www.appledaily.com.tw/local/20220107/WQZKUTU4TVC65CECPJDL5E4XPE/
# [353] v https://www.appledaily.com.tw/local/20220107/WGYDYGPANJCUFMX7GSY77UYENU/
# [354] v https://www.appledaily.com.tw/local/20220107/WE3LBUYXL5EERATIQWTG3EMRRM/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220107/U6IQLVCON5CZLDDNDSO5TGDRYI/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [355] x 失敗
# [356] v https://www.appledaily.com.tw/local/20220107/WPVW3KHIMVCKPKPKEBS3AY3ZII/
# [357] v https://www.appledaily.com.tw/local/20220107/XMDHR2HL6FEHZKBE5Q3SF74JPY/
# [358] v https://www.appledaily.com.tw/local/20220107/XS4JLVFVEJE3FHVKSPEHM7Z4ZI/
# [359] v https://www.appledaily.com.tw/local/20220107/ZJZOPRGWI5BVFPIZ4GMQNPNH3Q/
# [360] v https://www.appledaily.com.tw/local/20220108/4UTTZWCDKNB2JNV7O46SCALVU4/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220107/WYLN5QWV6BGV7GJSZQTQGZVBOU/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [361] x 失敗
# [362] v https://www.appledaily.com.tw/local/20220108/5273EEV3QNAD7CJLNCVXBC6OXE/
# [363] v https://www.appledaily.com.tw/local/20220108/C6MBGNIVMJFIROGTU3I36YAUSE/
# [364] v https://www.appledaily.com.tw/local/20220108/4R3L2ZXDTNHG5DGU526B5CLQVQ/
# [365] v https://www.appledaily.com.tw/local/20220108/CYLB2B3FDBBIPIL3NQSXYB762Y/
# [366] v https://www.appledaily.com.tw/local/20220108/6EDKGKXIBVBJVIH6GETX7AF2BY/
# [367] v https://www.appledaily.com.tw/local/20220108/5U37CDTTRJDIJOP2HLAMPEDP3U/
# [368] v https://www.appledaily.com.tw/local/20220108/DCAXVR3LAJEYVCOYBPLCINKAU4/
# [369] v https://www.appledaily.com.tw/local/20220108/D3F4Q7GRDBCJPEPDGWFHLBPZWA/
# [370] v https://www.appledaily.com.tw/local/20220108/FRUH5NVFNBFSTHPBS425BYEYSE/
# [371] v https://www.appledaily.com.tw/local/20220108/EXLT3U66QNERVOLFHPHOYH73JA/
# [372] v https://www.appledaily.com.tw/local/20220108/JE4QSPBNQ5AUFJQCKARKPI7XNU/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220108/3FIZZRFI2VE2DJCXM6MQUNG7XE/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [373] x 失敗
# [374] v https://www.appledaily.com.tw/local/20220108/IQPYWDO4C5EY3PEVLHXBXTCP6E/
# [375] v https://www.appledaily.com.tw/local/20220108/KHMYS4IGJNHTLAVTYYXAJCORTM/
# [376] v https://www.appledaily.com.tw/local/20220108/CYBBNUCVHNBS3PJ4DL4Z6NUBAE/
# [377] v https://www.appledaily.com.tw/local/20220108/KTUKWX5ONFE2FMJBWMC44YFFA4/
# [378] v https://www.appledaily.com.tw/local/20220108/JVKO5T4G7NFOLMJAZHCZMVZFO4/
# [379] v https://www.appledaily.com.tw/local/20220108/MMQSZWKVNBG4PIIUCQSRGRF6L4/
# [380] v https://www.appledaily.com.tw/local/20220108/LFJK2DVWJBHN3OMZRDIPCAI67E/
# [381] v https://www.appledaily.com.tw/local/20220108/MF3XQYQ46JCC3OSG3H7YMMWSAE/
# [382] v https://www.appledaily.com.tw/local/20220108/NV4AOIJ6L5AWPKSS4BHPW5V7AI/
# [383] v https://www.appledaily.com.tw/local/20220108/O53LLOLXXRDONGZKRQNVGVHOGY/
# [384] v https://www.appledaily.com.tw/local/20220108/OHR7UKOHOFCFNG2QJRICGUFXAU/
# [385] v https://www.appledaily.com.tw/local/20220108/OI2JZVGL5RCFLCJFM5O22NYRPA/
# [386] v https://www.appledaily.com.tw/local/20220108/PTJFL2IQJRHNFB5TUZA4OEXR2A/
# [387] v https://www.appledaily.com.tw/local/20220108/QKCX7OYHHJBDVEJLN5FDUZROC4/
# [388] v https://www.appledaily.com.tw/local/20220108/Q4EWCS5PHRCPLEGVWMDRMOQLDI/
# [389] v https://www.appledaily.com.tw/local/20220108/SCCRAWXVAJHIFIL5RQUMILMBOA/
# [390] v https://www.appledaily.com.tw/local/20220108/K27HIVYTEFERTEF3FDYTCD5IBI/
# [391] v https://www.appledaily.com.tw/local/20220108/RMTI3OSK3VE7ZC2Y5U2VWSKUAI/
# [392] v https://www.appledaily.com.tw/local/20220108/XWKHSTORVVFTPFX5CMQJINKTDQ/
# [393] v https://www.appledaily.com.tw/local/20220108/WGYLBCSBG5CKVLFA6FAE3MX4Z4/
# [394] v https://www.appledaily.com.tw/local/20220108/XORN6XINBJCHLLFONN72GPFDJE/
# [395] v https://www.appledaily.com.tw/local/20220108/ZK64QZEZFBBAHDANROS5WIIGWU/
# [396] v https://www.appledaily.com.tw/local/20220108/YORA7ASHLJDCZKJHGORLYBIFFA/
# [397] v https://www.appledaily.com.tw/local/20220108/T3VFB3NKGVEFFG6LWTDXXQ3KLA/
# [398] v https://www.appledaily.com.tw/local/20220108/ZTHNIQKJN5FJXOYESYTGKTGQNU/
# [399] v https://www.appledaily.com.tw/local/20220108/YWOJ56PAYFFJVPBHRK7KB4UFPQ/
# [400] v https://www.appledaily.com.tw/local/20220109/6IKVTLWQTFFR3B3KBKVNLNDQ54/
# [401] v https://www.appledaily.com.tw/local/20220109/5NPMLQVDOZHKXFZDTE7VI6L3J4/
# [402] v https://www.appledaily.com.tw/local/20220109/3B64ZKPZHNFHHOLMIULBOXFQHI/
# [403] v https://www.appledaily.com.tw/local/20220109/5LAC5R3UMBGTFGWKQC463DEUTQ/
# [404] v https://www.appledaily.com.tw/local/20220109/A7XIAEHBFNGGPJFJ525QXEGH6U/
# [405] v https://www.appledaily.com.tw/local/20220109/AWDX7JJLQZFTDNYHJILT6F7APQ/
# [406] v https://www.appledaily.com.tw/local/20220109/B2IQ5J6FKZFHVBIUBMIS26FJ3I/
# [407] v https://www.appledaily.com.tw/local/20220109/BBP7VAN3EZBCXGVWNE5K2UVGXE/
# [408] v https://www.appledaily.com.tw/local/20220109/C432TSW2CZGC7MBWJVEA3NY3JI/
# [409] v https://www.appledaily.com.tw/local/20220109/533KKIGSOBHOZEEJVQOVM52YBA/
# [410] v https://www.appledaily.com.tw/local/20220109/DON4HH7QMJF6VLVW47NZDNNGP4/
# [411] v https://www.appledaily.com.tw/local/20220109/E2W43EGRMVDGBBZLE3W52T44CU/
# [412] v https://www.appledaily.com.tw/local/20220109/E3SX5O5HVJEOHFJKR6M3NPEITI/
# [413] v https://www.appledaily.com.tw/local/20220109/ERCKDCIX6JFFTCGAXQV3CKGUHY/
# [414] v https://www.appledaily.com.tw/local/20220109/G5EWNXKDNJFWLKS6VKZGXMEKUM/
# [415] v https://www.appledaily.com.tw/local/20220109/GOXBTBVPUFG7NAI76RWEOHYZWE/
# [416] v https://www.appledaily.com.tw/local/20220109/BCSIAMXOBNCX7AF52MD6JMFOYI/
# [417] v https://www.appledaily.com.tw/local/20220109/EP2KKVU6DNDFBC33NBJSBXZEUE/
# [418] v https://www.appledaily.com.tw/local/20220109/73ZMWTHPHJHORCVKYFYNN2TATA/
# [419] v https://www.appledaily.com.tw/local/20220109/BQXVBVLEZRB7NJLBYG6UHCXXQU/
# [420] v https://www.appledaily.com.tw/local/20220109/JWYVMSEX2ZBHTFZADY4Z2PXZ2E/
# [421] v https://www.appledaily.com.tw/local/20220109/MA2WL2HIWNHGZJGSWQCKVAZYFA/
# [422] v https://www.appledaily.com.tw/local/20220109/N5ZSSXL27FF5XHK25VTVJ7OCDU/
# [423] v https://www.appledaily.com.tw/local/20220109/P635TNZ6LZHEHGFMPQ542J5F2I/
# [424] v https://www.appledaily.com.tw/local/20220109/PX6QMK65YJGW7FSJ7ZP36YUH6Q/
# [425] v https://www.appledaily.com.tw/local/20220109/U3Q7YGTICZA37LES7GBS5GR3R4/
# [426] v https://www.appledaily.com.tw/local/20220109/UI4PC7367FDU5IIPIJO67AV4B4/
# [427] v https://www.appledaily.com.tw/local/20220109/JGPTDUBFBZA5PIOXGXK72S5WWU/
# [428] v https://www.appledaily.com.tw/local/20220109/UKZBPXPNSJFAVOR52RQTAKMPKY/
# [429] v https://www.appledaily.com.tw/local/20220109/X4B2P2US5FDXZIYJTN6YM7FSRI/
# [430] v https://www.appledaily.com.tw/local/20220109/P4RYWGFLOFFPTCQEOZS3U3WBJI/
# [431] v https://www.appledaily.com.tw/local/20220109/TUYF2A7KZ5ELXDFUYDJJ4ZK254/
# [432] v https://www.appledaily.com.tw/local/20220109/Z7CPIHKN4NESPH2ULHGEEXSDEU/
# [433] v https://www.appledaily.com.tw/local/20220109/ZHBEP5RQDFFF3EKGOURBZO33VI/
# [434] v https://www.appledaily.com.tw/local/20220109/W7KTJZKOLVEPJNSIM3UFVOCE2Q/
# [435] v https://www.appledaily.com.tw/local/20220109/ZE5UE7CSE5CZRJZLFRQIDKTHJU/
# [436] v https://www.appledaily.com.tw/local/20220109/WIAFSG4LUFH23DZGM6D7SBFDUQ/
# [437] v https://www.appledaily.com.tw/local/20220110/43RWQWPOR5FT7JBWUIBU4VD3XM/
# [438] v https://www.appledaily.com.tw/local/20220110/3P7VLSKH4NDWDA7IUXGHNC7WKU/
# [439] v https://www.appledaily.com.tw/local/20220110/3ZYM3IKPXVGEJFNBZQF25K6UHY/
# [440] v https://www.appledaily.com.tw/local/20220109/Y5NB2EDO7JHGTGFFXCS6EHUH3U/
# [441] v https://www.appledaily.com.tw/local/20220110/5RBCPRCHL5HXRFODNQ7H7BUQEY/
# [442] v https://www.appledaily.com.tw/local/20220110/3QILPPNBSJGT7NGUTC45CQJ5M4/
# [443] v https://www.appledaily.com.tw/local/20220110/5LAIOLTYXREEJDYW5E4JBRLMOQ/
# [444] v https://www.appledaily.com.tw/local/20220110/6RWXAWOUERB3VAN62OKXAPRAVI/
# [445] v https://www.appledaily.com.tw/local/20220110/4R5HJGGIYRFWTM35W4BPNFZEIE/
# [446] v https://www.appledaily.com.tw/local/20220110/6YSAPB3XMBAM3MSWC3QRLOBKXU/
# [447] v https://www.appledaily.com.tw/local/20220110/75VGXCLRWVAIHFTJI55B5RUNNU/
# [448] v https://www.appledaily.com.tw/local/20220110/AQYJ57QGCBBINEQLWBOD4YRTTM/
# [449] v https://www.appledaily.com.tw/local/20220110/C2OYVPXTPRF5NM7RZKSCBWKVCA/
# [450] v https://www.appledaily.com.tw/local/20220110/BNPOQPM3VREW7IT4WQRSJLAXCE/
# [451] v https://www.appledaily.com.tw/local/20220110/AJ2K5IFSLNDRZMKPN2YZXIJEIM/
# [452] v https://www.appledaily.com.tw/local/20220110/CMGYSRIGUFB6JD7X4KR5WCWLKQ/
# [453] v https://www.appledaily.com.tw/local/20220110/EYCDYLYZ5VFHJECDFEEXZV6PJ4/
# [454] v https://www.appledaily.com.tw/local/20220110/EF4GYAAVYVB7NNX7PJ7QMMKZPA/
# [455] v https://www.appledaily.com.tw/local/20220110/G4KPMSYTU5C5ZDMIJU6ZVHKM74/
# [456] v https://www.appledaily.com.tw/local/20220110/IJLOQ4Y7NZBMZI3OCAN4XJ3WKY/
# [457] v https://www.appledaily.com.tw/local/20220110/DYVJ7AIZPVDZNFB67RT72IQDUY/
# [458] v https://www.appledaily.com.tw/local/20220110/I2NU6O5RCRC4RFV24VKE7ABQ3E/
# [459] v https://www.appledaily.com.tw/local/20220110/J7FGBTPFYZBXRAZZ3DTG4LNBCE/
# [460] v https://www.appledaily.com.tw/local/20220110/B7C3RJYF7JCZDLXODD5MVDGXNM/
# [461] v https://www.appledaily.com.tw/local/20220110/JMJVTU6X6FDJDF6THQAYRVE2OA/
# [462] v https://www.appledaily.com.tw/local/20220110/JOBU5RZBUZHXLDAZO3RB6V7C6I/
# [463] v https://www.appledaily.com.tw/local/20220110/K43OIIATFBGXZO35RRSAXHLI2M/
# [464] v https://www.appledaily.com.tw/local/20220110/4A7GNOOGWNEU3FNI7J72J36CJA/
# [465] v https://www.appledaily.com.tw/local/20220110/KRGIU2OFVZBH3DSIV4M7SEMLT4/
# [466] v https://www.appledaily.com.tw/local/20220110/L3K66Z666FGMTAQXEEQCKZZ3ZY/
# [467] v https://www.appledaily.com.tw/local/20220110/LSSP7RCFR5FKDBSISY7ZUYGH2E/
# [468] v https://www.appledaily.com.tw/local/20220110/JKXNECFDDZFIHDL7JRB6DQO5KM/
# [469] v https://www.appledaily.com.tw/local/20220110/LNC3VYCUW5GW3PHRQLSGTPOWAU/
# [470] v https://www.appledaily.com.tw/local/20220110/IQF3A4WEYBETJAWPFRBEA5SMMA/
# [471] v https://www.appledaily.com.tw/local/20220110/NBRTJLZW5JC3DMAORIXJ3FNJ6I/
# [472] v https://www.appledaily.com.tw/local/20220110/N7OTCAM4O5FDJK4IZQ32QIA2BE/
# [473] v https://www.appledaily.com.tw/local/20220110/O2LV5TLOFZHK7MXAR7L4DGFWLA/
# [474] v https://www.appledaily.com.tw/local/20220110/PX3LPQPMKVA4BB3EIHMIAHBBV4/
# [475] v https://www.appledaily.com.tw/local/20220110/NPRUEDHIOND35GF5MZO7TWD5V4/
# [476] v https://www.appledaily.com.tw/local/20220110/R62HDYEYANCQRE6CXLSKKYERRY/
# [477] v https://www.appledaily.com.tw/local/20220110/QHH5FSPA3NDLTGCB5H4BZXEFMY/
# [478] v https://www.appledaily.com.tw/local/20220110/QY4VE5A5CVGAHFYUL3O6AJBAGA/
# [479] v https://www.appledaily.com.tw/local/20220110/U63L6GZNKBFXFPKT3PEEKRUBEU/
# [480] v https://www.appledaily.com.tw/local/20220110/U4CTDZBACRCQBDCQZUOV6L33EM/
# [481] v https://www.appledaily.com.tw/local/20220110/UADK36NRIJGWHBU4O7676F7IHA/
# [482] v https://www.appledaily.com.tw/local/20220110/R4DJB2QWI5GRXHIMN3NKUKHXKI/
# [483] v https://www.appledaily.com.tw/local/20220110/UGMCWGT7NZCKZCCML54BRYU7OU/
# [484] v https://www.appledaily.com.tw/local/20220110/VBT7OVXNABDODPJ7VH6ALG7ZTI/
# [485] v https://www.appledaily.com.tw/local/20220110/V2VWMGK7K5ECLIIFPIFHSCHPXQ/
# [486] v https://www.appledaily.com.tw/local/20220110/VXQSLF22UJCN5BW6ADKLBOGIGQ/
# [487] v https://www.appledaily.com.tw/local/20220110/Y2LTTNIRXZHXPHJVVMFDTWLE6M/
# [488] v https://www.appledaily.com.tw/local/20220110/QIDOC7DX2BFYBPDTDMLIUHIEFM/
# [489] v https://www.appledaily.com.tw/local/20220110/VOCCT7BBU5HLLJSVCJKI2GNRSE/
# [490] v https://www.appledaily.com.tw/local/20220110/Y67XQPT3EJHUBDETK64P6BZGNI/
# [491] v https://www.appledaily.com.tw/local/20220110/YQV6VLGVAVHBNPOLNDWH7ZPRTQ/
# [492] v https://www.appledaily.com.tw/local/20220111/4DKYEESR5BBXNLUGJ7F3DIE4OU/
# [493] v https://www.appledaily.com.tw/local/20220111/2TAXKMYEIJGYDACLA76FGK2MMY/
# [494] v https://www.appledaily.com.tw/local/20220111/55TWARUD45DN3OE6E7BNMC5FMA/
# [495] v https://www.appledaily.com.tw/local/20220111/633ILEGNQVADXMNPOYHOE5ZIKE/
# [496] v https://www.appledaily.com.tw/local/20220111/66OI73TFZ5EXJGF2ZCMZQNE5OY/
# [497] v https://www.appledaily.com.tw/local/20220111/6P6K2KJZTFA6LAHD2IJPHZOXLI/
# [498] v https://www.appledaily.com.tw/local/20220110/Y2VZRY7P7ZEIVHQOW5U77RHYMM/
# [499] v https://www.appledaily.com.tw/local/20220111/6CJAYZDXXNGZJA55YCA44N4GKQ/
# [500] v https://www.appledaily.com.tw/local/20220111/A7A2IYUVPRERBEMRUJUVK4OPCE/
# [501] v https://www.appledaily.com.tw/local/20220111/7PUORMWPMBEUFCZG5T7YWDHVA4/
# [502] v https://www.appledaily.com.tw/local/20220111/6UTZMAYENVA7RNHX4CVZFJOOIA/
# [503] v https://www.appledaily.com.tw/local/20220111/BMG2FE4ZFBHKJJWWX7SHLYAYVA/
# [504] v https://www.appledaily.com.tw/local/20220111/AEF54GOAEZH6HK5ULGWRNMPWPM/
# [505] v https://www.appledaily.com.tw/local/20220111/BUCJLK6Z3FG3NOJZKFGYJ66DBY/
# [506] x 失敗
# [507] v https://www.appledaily.com.tw/local/20220111/C5UROLEHYFAMXB7RQDOTF4QL4A/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220110/V3G7TEGPV5E4JML3LJQFZTNIC4/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [508] x 失敗
# [509] v https://www.appledaily.com.tw/local/20220111/FYL7VALYC5GRHP4PCUP4A5FLUM/
# [510] v https://www.appledaily.com.tw/local/20220111/G2FTFTZJK5D4JPAXY5MLWUECH4/
# [511] v https://www.appledaily.com.tw/local/20220111/GCYOZ23AHZFCPIZ3NTHJH67DSE/
# [512] v https://www.appledaily.com.tw/local/20220111/F2PUN22IUNHUJAR7KOX2YBAWAQ/
# [513] v https://www.appledaily.com.tw/local/20220111/I4AG6EDSVBGG5E3IROPNN3IBCQ/
# [514] v https://www.appledaily.com.tw/local/20220111/IBKA6TUCQ5EA7G5OZCPF3LIQCE/
# [515] v https://www.appledaily.com.tw/local/20220111/ILXBI2UUTNCELGD4RHIADZDKJU/
# [516] v https://www.appledaily.com.tw/local/20220111/JI75SYQEAZAVPPK37YHSXG764Y/
# [517] v https://www.appledaily.com.tw/local/20220111/KOJYMB7TOBHFHHUYESGWVVQZ2U/
# [518] v https://www.appledaily.com.tw/local/20220111/KXALRYY6OVAE7GNWGRLKKCPZZY/
# [519] v https://www.appledaily.com.tw/local/20220111/LF2QKKLNLNBODA66KGW422YYAM/
# [520] v https://www.appledaily.com.tw/local/20220111/DJ7M4H777BEWFFM7ETHHGD6PKE/
# [521] v https://www.appledaily.com.tw/local/20220111/MJXUPX3ZDNFXHPQHCMIKREQRIA/
# [522] v https://www.appledaily.com.tw/local/20220111/NCLMMYVW7RE5PPJ77UJVODOYT4/
# [523] v https://www.appledaily.com.tw/local/20220111/DISVHKRBYJCZPBXP5IRG5Z2GPA/
# [524] x 失敗
# [525] v https://www.appledaily.com.tw/local/20220111/NAYHOCPT35G5JJLA2ZN2TYDACI/
# [526] v https://www.appledaily.com.tw/local/20220111/NKNIGFR3KFAE7JMZ2YTD7HUANI/
# [527] v https://www.appledaily.com.tw/local/20220111/OI6CC6NCBRBZRMABAAH2S4IBKI/
# [528] v https://www.appledaily.com.tw/local/20220111/PCBTOFP6QVDV5AQQH2HVJAI4ME/
# [529] v https://www.appledaily.com.tw/local/20220111/OKEPB2V2ABEMRISGCDWX4ZCTYQ/
# [530] v https://www.appledaily.com.tw/local/20220111/OWEURUSP7NHRBELG5OSBDGMNXM/
# [531] v https://www.appledaily.com.tw/local/20220111/QMM7EAKDQBHETGFAASBZPUUFOI/
# [532] v https://www.appledaily.com.tw/local/20220111/ROW2QGVVZRGBHL5IZUQNVWSXEU/
# [533] v https://www.appledaily.com.tw/local/20220111/RUHIOX64FNAGVJVF2D5IW6GWJU/
# [534] v https://www.appledaily.com.tw/local/20220111/SP6OFY3FSFFNXKGGN7ICYEKQ5Q/
# [535] v https://www.appledaily.com.tw/local/20220111/U3TCBV7Y4BFQVB4Z772ON2ZBR4/
# [536] v https://www.appledaily.com.tw/local/20220111/TIMQV4N6UJF63IHB3WHNJ6UEHQ/
# [537] v https://www.appledaily.com.tw/local/20220111/UI5VPTK5HNH6JB6ISUAMTYWTQA/
# [538] v https://www.appledaily.com.tw/local/20220111/ULDSISZBGRGNPNUQIUVPIW5EBA/
# [539] v https://www.appledaily.com.tw/local/20220111/VM3IMKAIVJG67OGTOBAGDN75LU/
# [540] v https://www.appledaily.com.tw/local/20220111/W7WX2PXJINE35E4RFWQIFJQZUA/
# [541] v https://www.appledaily.com.tw/local/20220111/VCO3AFQYBFCMHLTJXNNRB4XQI4/
# [542] v https://www.appledaily.com.tw/local/20220111/WOVELVABWBHA3KIHWRB4XMILXE/
# [543] v https://www.appledaily.com.tw/local/20220111/XEYVALLJTFDNTO4N2UVQ6MBRPE/
# [544] v https://www.appledaily.com.tw/local/20220111/WZWXWHICPFD65POBTP4QY5BJUY/
# [545] v https://www.appledaily.com.tw/local/20220111/S4YSVXIYNBGE7CFCEJMUC3I6PI/
# [546] v https://www.appledaily.com.tw/local/20220111/XHJMV2EXOBDTXJGKP4PE72LDDI/
# [547] v https://www.appledaily.com.tw/local/20220111/XUMBXYRYG5DALNQON4ZBH77HLM/
# [548] v https://www.appledaily.com.tw/local/20220111/Y7RMKIFW6JDPLLDJUFA5ALKO54/
# [549] v https://www.appledaily.com.tw/local/20220111/YNFZLRXN2VCLFGMTTDQFTYSF7A/
# [550] v https://www.appledaily.com.tw/local/20220111/Z5HKZSLAPNDFDMFQFNTVZJJ4ZY/
# [551] v https://www.appledaily.com.tw/local/20220111/SPUOYI43IFC2DEHX6MS7BS43CY/
# [552] v https://www.appledaily.com.tw/local/20220112/22PVFFA5NNADFFEPGD7LGAS2X4/
# [553] v https://www.appledaily.com.tw/local/20220112/2KY5VL7UAVAUVEDUQKRA45KCQI/
# [554] v https://www.appledaily.com.tw/local/20220111/ZXSW2DUODZGPDK7R5YN4ECDKOA/
# [555] v https://www.appledaily.com.tw/local/20220112/3EX2ZIDX7BBNVB2APG2A6YSPSM/
# [556] v https://www.appledaily.com.tw/local/20220112/3HO74BLIQNE7DN3OIB4NVVACTQ/
# [557] v https://www.appledaily.com.tw/local/20220112/3LHWIPTBTNCTFNWNIXSR3ELOY4/
# [558] x 失敗
# [559] v https://www.appledaily.com.tw/local/20220112/62VDHHMZQVEAFNEWK4NI62OZ5I/
# [560] v https://www.appledaily.com.tw/local/20220112/5JITSZTFSVCGLN3OJJ2CIOHTDY/
# [561] v https://www.appledaily.com.tw/local/20220112/5LL74JKUURF7HJOUVY6KVLTAEQ/
# [562] v https://www.appledaily.com.tw/local/20220112/6ZMPAH7ATZGFXKL7DFI6QYSM3I/
# [563] v https://www.appledaily.com.tw/local/20220112/6WIBPF63RRHULIZQR7UL626B3M/
# [564] v https://www.appledaily.com.tw/local/20220112/AUJQ7I7KXBF6HNHMUZF6IE2AHI/
# [565] v https://www.appledaily.com.tw/local/20220112/ANFOWCIYQZBPLCNXSKFOOCMC4I/
# [566] v https://www.appledaily.com.tw/local/20220112/CBSYGGXINRENDJWDFG66G24FPQ/
# [567] v https://www.appledaily.com.tw/local/20220112/2XDV6YTZLJFUJM2XMLFEK67QQQ/
# ...
# [1453] x 失敗
# [1454] v https://www.appledaily.com.tw/local/20220127/XKXUEV2UTVAEPBV55XC7Q3WMGY/
# [1455] v https://www.appledaily.com.tw/local/20220128/4ECJRHISCVCZZC55K7ZLQOJTF4/
# [1456] x 失敗
# [1457] v https://www.appledaily.com.tw/local/20220128/3LH4XCJS2NFQ3IBBRY3EJ2QSTY/
# [1458] v https://www.appledaily.com.tw/local/20220128/2VP2O7YPN5CDTBD3CISGP47SKY/
# [1459] v https://www.appledaily.com.tw/local/20220128/5KCJ2IKB7RGLZJBSTWZQFJC25M/
# [1460] v https://www.appledaily.com.tw/local/20220128/754A6N4ZFZEVLAAANVFRTB3G6I/
# [1461] v https://www.appledaily.com.tw/local/20220128/AOSPTKMZ4BGEPP6D5IFIL27MOM/
# [1462] v https://www.appledaily.com.tw/local/20220128/6F37MIDCHBGM7ETEYB2C7C3QJM/
# [1463] v https://www.appledaily.com.tw/local/20220128/D4ZMO7XMRZB4DKP7N2L7QRJGYU/
# [1464] v https://www.appledaily.com.tw/local/20220128/6OPR7GHSY5G65E35DRJYKYCE2Y/
# [1465] v https://www.appledaily.com.tw/local/20220128/BFGM6S2N3RDQDCWFQIQDAXJ7LA/
# [1466] v https://www.appledaily.com.tw/local/20220128/HF5374SP25E7HAOMTS5HPFLPAE/
# [1467] v https://www.appledaily.com.tw/local/20220128/HG7NE5VKHNCNZJOJ63SMJ4VO6I/
# [1468] v https://www.appledaily.com.tw/local/20220128/G4EJCCRCJVGCRPBWH53T3I5YEI/
# [1469] v https://www.appledaily.com.tw/local/20220128/BTCN6DY2IVEFRFVQMBC3GCNOV4/
# [1470] v https://www.appledaily.com.tw/local/20220128/HSV4HYBQNZAGZFNM5YANAS7TOM/
# [1471] v https://www.appledaily.com.tw/local/20220128/HPO7D4MUGVBRZMIB6DPOQYQWAA/
# [1472] v https://www.appledaily.com.tw/local/20220128/AZFEJLYSAZACVJDPWXLG5TEA64/
# [1473] v https://www.appledaily.com.tw/local/20220128/IGGEIGGXS5BRNBVCIXES63WX7Q/
# [1474] v https://www.appledaily.com.tw/local/20220128/JMIVGMHAQRFLPCEBPQ2X6HWQTA/
# [1475] v https://www.appledaily.com.tw/local/20220128/K4NNIBFIKJA7JGVUERBIG7FR3E/
# [1476] v https://www.appledaily.com.tw/local/20220128/KHU7IPBY2FCD3HGQKSL55AC5YE/
# [1477] v https://www.appledaily.com.tw/local/20220128/HUJBA6BCRVD4FKJG22TAG4VUHI/
# [1478] v https://www.appledaily.com.tw/local/20220128/JTMJ2R7E4BFVBIRRZ5GJSYKLS4/
# [1479] v https://www.appledaily.com.tw/local/20220128/JONJVOV3BVGU7B6VFMG7SJFUJU/
# [1480] v https://www.appledaily.com.tw/local/20220128/MQNWJLWLUBE25A3VFBJ6DD6KNI/
# [1481] v https://www.appledaily.com.tw/local/20220128/GMCX4GI4NRBBTHGKVI7YM3RVI4/
# [1482] v https://www.appledaily.com.tw/local/20220128/KL7U6XLC3JD2JB4CJ2UR2XJT5Q/
# [1483] v https://www.appledaily.com.tw/local/20220128/KSSUU2CWT5FQLKGTC6BDJWAKDI/
# [1484] v https://www.appledaily.com.tw/local/20220128/NEVRPLKRRFDDTB54PQIAKAFPRU/
# [1485] v https://www.appledaily.com.tw/local/20220128/ODR7Z6VWAJHM5PRRTRCKLM74D4/
# [1486] v https://www.appledaily.com.tw/local/20220128/L2U5QY5WZVA63KL6TZR5HPZXSE/
# [1487] v https://www.appledaily.com.tw/local/20220128/NF3JQ5BBORANVGXTWYMBZLBDPA/
# [1488] v https://www.appledaily.com.tw/local/20220128/OSVDKOVBGRGMNOTC2FZ767KDXQ/
# [1489] x 失敗
# [1490] v https://www.appledaily.com.tw/local/20220128/QNUU2PKGAZB5JCARFSPEL25TW4/
# [1491] v https://www.appledaily.com.tw/local/20220128/SE5YGDUQMBG4HFHT2AXN2SFC7A/
# [1492] v https://www.appledaily.com.tw/local/20220128/S2WKV7YS6RHG3IOET6QXO2PUBY/
# [1493] v https://www.appledaily.com.tw/local/20220128/SMIQEWUM4VBERBPATSUPR2HK6E/
# [1494] v https://www.appledaily.com.tw/local/20220128/SXRONI64LJF6PDFCRZIIPVXP5Y/
# [1495] v https://www.appledaily.com.tw/local/20220128/QF2RNZHEGFFABLGW5V5TV3SIH4/
# [1496] v https://www.appledaily.com.tw/local/20220128/QJJ66Z6EVRECLEA5TJ4MLOABHA/
# [1497] v https://www.appledaily.com.tw/local/20220128/SLW4LSUVLZEPNCFF2WSN3RRYWQ/
# [1498] v https://www.appledaily.com.tw/local/20220128/TE2COEVOFBECNDA25C3V7UUIUE/
# [1499] v https://www.appledaily.com.tw/local/20220128/UVYGFUW3SFBM3MUQFVJZYR5C4M/
# [1500] v https://www.appledaily.com.tw/local/20220128/VQOJXDAYTZDUJHBH5CWXEGLNOM/
# [1501] v https://www.appledaily.com.tw/local/20220128/XDQQ7P5KLFHARJC6ANN3EZ7WQI/
# [1502] v https://www.appledaily.com.tw/local/20220128/XMSE5Q2RCNGHXGRJ2FMWAW7PHA/
# [1503] v https://www.appledaily.com.tw/local/20220128/XHZHZJPSRZAKVLF2JVYEJB63QE/
# [1504] v https://www.appledaily.com.tw/local/20220128/UGWP7ZP7HBAM3CDB4HAX3MXE4E/
# [1505] v https://www.appledaily.com.tw/local/20220128/PK4NCOA6MZGFDKVICMTTYHUWZE/
# [1506] v https://www.appledaily.com.tw/local/20220128/YOUOPL6QEFEDNCNH2RUDYEIXCA/
# [1507] v https://www.appledaily.com.tw/local/20220128/XX4KIZ4OANBMTPBM3EYQC6M7SI/
# [1508] v https://www.appledaily.com.tw/local/20220128/YREUXEAKJRGSHHOUC4QKSE4KKU/
# [1509] v https://www.appledaily.com.tw/local/20220129/4U667DOKQRFNZFR5AZXW7ERCZM/
# [1510] v https://www.appledaily.com.tw/local/20220129/6CAOVELU5FHC3NNPY44ONIZKXQ/
# [1511] v https://www.appledaily.com.tw/local/20220128/WJV4FJINIRBNRGISL6LIRVLAV4/
# [1512] v https://www.appledaily.com.tw/local/20220129/7CFDPHYA6NDCLG5BMP7WNVF4LI/
# [1513] v https://www.appledaily.com.tw/local/20220129/5KA4PECPLFHZZGPDQEFRZK7LXA/
# [1514] v https://www.appledaily.com.tw/local/20220129/BVDNITX3IVAEXISFMN6G3D5LHQ/
# [1515] v https://www.appledaily.com.tw/local/20220129/AW4F6AX6Q5GLNGOVPC4ZFCUBFU/
# [1516] v https://www.appledaily.com.tw/local/20220128/ZCREAY27DBBLTHIGHDESEFFRPY/
# [1517] v https://www.appledaily.com.tw/local/20220129/5MRAS655XNFTVKWEWNQC3M72BU/
# [1518] v https://www.appledaily.com.tw/local/20220129/CADFWCCQ4VFFJLF3VAKROIRPOU/
# [1519] v https://www.appledaily.com.tw/local/20220129/GW7DAWS45JHGXHPSWL3VXTYODM/
# [1520] v https://www.appledaily.com.tw/local/20220129/EA5FI2H73ZGR3CBTTRO4ZBGBYA/
# [1521] v https://www.appledaily.com.tw/local/20220129/HMS37XEZOBAENCUEFWLBIO6KZI/
# [1522] v https://www.appledaily.com.tw/local/20220129/DMHVET3GCJDL3EYWNC7RDMLT5A/
# [1523] v https://www.appledaily.com.tw/local/20220129/HR5XJAC235HS7GFFUEN25RZKP4/
# [1524] v https://www.appledaily.com.tw/local/20220129/BIIPPVGRNZEJ3PX5UFNH4GPUQI/
# [1525] v https://www.appledaily.com.tw/local/20220129/IR5LQ4KBXBFQ7BDRTG4CYCQOXM/
# [1526] v https://www.appledaily.com.tw/local/20220129/J677DYQEBNB7VEOUHXJAEIZ5KM/
# [1527] v https://www.appledaily.com.tw/local/20220129/KELQAQRW2VBEDC2Y4WDENHYYF4/
# [1528] v https://www.appledaily.com.tw/local/20220129/KXYWIU43UBAV3ELN6EMKQMC77E/
# [1529] v https://www.appledaily.com.tw/local/20220129/NHOGLOBZIRDLJLP5NN275KWP34/
# [1530] v https://www.appledaily.com.tw/local/20220129/OSGHPG4V75FARGADBAN3CK4TUA/
# [1531] v https://www.appledaily.com.tw/local/20220129/GXX4IN2MNVGGNJS6DOBZI67MVA/
# [1532] v https://www.appledaily.com.tw/local/20220129/Q3MNCTYUWNGB7MNWM4QNEDOO6A/
# [1533] v https://www.appledaily.com.tw/local/20220129/QF5NWFSFFNCEVGEUSZXYDFKSEY/
# [1534] v https://www.appledaily.com.tw/local/20220129/R2ABMOQYWBBJ3G53KAYDN53NA4/
# [1535] v https://www.appledaily.com.tw/local/20220129/QZTARL33UJDQJF5PKPXEZE4MNU/
# [1536] v https://www.appledaily.com.tw/local/20220129/RHDC3FZTTZGLXIPX2MGMGMN7KU/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220129/CGIVCWZK7NDLHCCBRWHYNYRGBY/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [1537] x 失敗
# [1538] v https://www.appledaily.com.tw/local/20220129/SI336QTW5NEYTJLDYSXBPLAYDY/
# [1539] v https://www.appledaily.com.tw/local/20220129/SFG3YQT5VBCXHH4YHTKUUOQ5JA/
# [1540] v https://www.appledaily.com.tw/local/20220129/UFDKTAW6RNG6JKT55YY2V4AEVQ/
# [1541] v https://www.appledaily.com.tw/local/20220129/TTB3HT55CFH2BGOJTV2AUU6QPA/
# [1542] v https://www.appledaily.com.tw/local/20220129/UV75M5ALI5CCVPVH4NG5Z5QJ7E/
# [1543] v https://www.appledaily.com.tw/local/20220129/WG24267CWZAHVJXEI2BKZMAFEE/
# [1544] v https://www.appledaily.com.tw/local/20220129/WWCMSPGNFNEMJPY6UOJTXJ4MI4/
# [1545] v https://www.appledaily.com.tw/local/20220129/WAZGYWVOKJGWTNQN5ZB7CWHTFI/
# [1546] v https://www.appledaily.com.tw/local/20220129/XHOYEEXYTZEHFKQBVRQJF4YSIQ/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220129/NA2F6MBHIBAK5CMCEZK37PKABA/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [1547] x 失敗
# [1548] v https://www.appledaily.com.tw/local/20220129/PD5M4GTB4NDXZLNGJXREE7JNXI/
# [1549] v https://www.appledaily.com.tw/local/20220129/YIQCHEVCN5HT7DPGTWRVNF7LJQ/
# [1550] v https://www.appledaily.com.tw/local/20220129/ZTEWLUOSX5DVHPYCGPAP7M7BL4/
# [1551] v https://www.appledaily.com.tw/local/20220130/33MRKPMD35FULHCLG5ES55WLUM/
# [1552] v https://www.appledaily.com.tw/local/20220130/5J27TP6U35BXRNBBRAGP56W4YY/
# [1553] v https://www.appledaily.com.tw/local/20220130/3XFXARUY2BF3FJB46BYVASJSB4/
# [1554] v https://www.appledaily.com.tw/local/20220130/7HQNOO2O4ZEULPVA4WTNAX75ME/
# [1555] v https://www.appledaily.com.tw/local/20220129/UPRXYAWKKNDCJKZTSUMJT4GXN4/
# [1556] v https://www.appledaily.com.tw/local/20220130/7FQB6YGVLFEIDHBLOCPV6IOGDM/
# [1557] v https://www.appledaily.com.tw/local/20220130/7YPDW4SHCRBV5HP65OKIE3256A/
# [1558] v https://www.appledaily.com.tw/local/20220130/BXATPSFO4NC27HDJQRN35HCIZU/
# [1559] v https://www.appledaily.com.tw/local/20220130/CYKHYPSV4ZCFDAWI3P6YRNGPZI/
# [1560] v https://www.appledaily.com.tw/local/20220130/E7GGHL3TKNHPRGNJ3XLGBZ5XHU/
# [1561] v https://www.appledaily.com.tw/local/20220130/EL5IAMS6IJBMNMNXXE4Z55HZXU/
# [1562] v https://www.appledaily.com.tw/local/20220129/YVT4OALZGZCDNDVHGJXZASHCBM/
# [1563] v https://www.appledaily.com.tw/local/20220130/AKCMHDY4ENHEFGEEXZPGGBSYAY/
# [1564] v https://www.appledaily.com.tw/local/20220130/EXLZEFF2DNG3XMMNTKT2KCAKWU/
# [1565] v https://www.appledaily.com.tw/local/20220130/D6YOPMX4R5EK5ENUYX7EH2FE2U/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220129/Z3ABAW5ZQZH4PMSFR727SUZOBE/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [1566] x 失敗
# [1567] v https://www.appledaily.com.tw/local/20220130/FEVSSUMXPBFMXE3GIOCJDKQDSA/
# [1568] v https://www.appledaily.com.tw/local/20220130/GD6OC2BP7VEP3PK54P5Y7I37MM/
# [1569] v https://www.appledaily.com.tw/local/20220130/GER7GYD5OJD3HFN6AI7XREQDSU/
# [1570] v https://www.appledaily.com.tw/local/20220130/FTF3MTDDKVG3FPJLLMAGLAZJWA/
# [1571] v https://www.appledaily.com.tw/local/20220130/HFZEANBLZ5C43A2RMCGIPAG7AQ/
# [1572] v https://www.appledaily.com.tw/local/20220130/I44L273G3RDCXEQFN43XYMZJN4/
# [1573] v https://www.appledaily.com.tw/local/20220130/MPFZYE6T2BA5FD455K3J44GARY/
# [1574] v https://www.appledaily.com.tw/local/20220130/M7WEERMIVFBLLNR5V7TU62VUCM/
# [1575] v https://www.appledaily.com.tw/local/20220130/KCIYMXYUWBC67DHUVXQJWX633I/
# [1576] v https://www.appledaily.com.tw/local/20220130/G4RKM4YHTJA45JFJ5D6XJ3B7FU/
# [1577] v https://www.appledaily.com.tw/local/20220130/N6VRQJP3INFYDE3VGFX73WIUVI/
# [1578] v https://www.appledaily.com.tw/local/20220130/OV4SAYC775FUBL2657RM5XIMMM/
# [1579] v https://www.appledaily.com.tw/local/20220130/PFM6YGYQIJA3FMVCPRB4KHM35E/
# [1580] v https://www.appledaily.com.tw/local/20220130/QOMNK5M3MZGVJH5G6ZMADDUMRI/
# [1581] v https://www.appledaily.com.tw/local/20220130/QYEIKLTDQBDJ7J65ISFQASMY2E/
# [1582] v https://www.appledaily.com.tw/local/20220130/Q2PKE3ZACZGBXBIVBVTTJO7P7Y/
# [1583] v https://www.appledaily.com.tw/local/20220130/R37AJGWB7NESRDFBTUPECM5QQE/
# [1584] v https://www.appledaily.com.tw/local/20220130/S6MYBHPCCJBRRGKHOBQ55HYKFQ/
# [1585] v https://www.appledaily.com.tw/local/20220130/RVKX35H76BDANBED4P4Y4GXREQ/
# [1586] v https://www.appledaily.com.tw/local/20220130/SG5D6SITDFHC7PBKMZQ4KSJRAQ/
# [1587] v https://www.appledaily.com.tw/local/20220130/R3FH3L6I7ZERLKJKQDASKQANOY/
# [1588] v https://www.appledaily.com.tw/local/20220130/SMEB4UHLGRC3BKTCBBAO5OT2BE/
# [1589] v https://www.appledaily.com.tw/local/20220130/QSU46TPOCRC6FB3DEJSO6ME6WY/
# [1590] v https://www.appledaily.com.tw/local/20220130/TTBSW4MUDBGGZLO6XTHFK3533Y/
# [1591] v https://www.appledaily.com.tw/local/20220130/UYZ4A5OWARA2LDQQYZULM5TGMY/
# [1592] v https://www.appledaily.com.tw/local/20220130/TXEZ5TYC45CEFIQ6YJ5DGE63EU/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220130/MX7SC6GC6ZB7PN2GYX37D5EQHQ/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [1593] x 失敗
# [1594] v https://www.appledaily.com.tw/local/20220130/VJQQN4ONDVCBTE55QGCXYAMRTE/
# [1595] v https://www.appledaily.com.tw/local/20220130/XPP4YSYRBFEYHIIJDF73Q2UNYQ/
# [1596] v https://www.appledaily.com.tw/local/20220130/YDNXLOZCPRCORGZYTB5YJ3T2U4/
# [1597] v https://www.appledaily.com.tw/local/20220130/WGRNORKNFZADHJKTUM7HL67XQE/
# [1598] v https://www.appledaily.com.tw/local/20220131/4HKF3NLDTVGMBMBUTYBASMETT4/
# [1599] v https://www.appledaily.com.tw/local/20220131/4TIFGJ4YKJHQPCGJLEQQ7242OU/
# [1600] v https://www.appledaily.com.tw/local/20220131/4PFWMUIETBALFOENCE5O5QF3I4/
# [1601] v https://www.appledaily.com.tw/local/20220131/5IZ3HWUAFZCBPGFNXF7NU6LVC4/
# [1602] v https://www.appledaily.com.tw/local/20220130/TQ6QL6AELJEN5DI75VKSCJWJN4/
# [1603] v https://www.appledaily.com.tw/local/20220131/6LDP3VUC35E25KVAPIAVK4K3WY/
# [1604] v https://www.appledaily.com.tw/local/20220131/ANGOVZBGDZBE3DWIWVBBEDMFTQ/
# [1605] v https://www.appledaily.com.tw/local/20220131/4U4KDO4SDFEAPLQXJYCP545ZJM/
# [1606] v https://www.appledaily.com.tw/local/20220131/BPQNJ4DAEZBHDCNNKXJLIVV4H4/
# [1607] v https://www.appledaily.com.tw/local/20220131/C5MTBA6E6NANLECFYJEOKBHX6A/
# [1608] v https://www.appledaily.com.tw/local/20220131/ATUXW2VK2NCDNNJGGCPGT4US6I/
# [1609] v https://www.appledaily.com.tw/local/20220131/AIGK6OOKRRHRFEKFQ5BIC22Z44/
# [1610] v https://www.appledaily.com.tw/local/20220131/CDAF3HLMRVCZ5J6THIMMUEKVS4/
# [1611] v https://www.appledaily.com.tw/local/20220131/CALHC5RR55GCROX2RQGU47ARKU/
# [1612] v https://www.appledaily.com.tw/local/20220131/C6NMYBM4ZFDZ5FZIXDXYFA67ZQ/
# [1613] v https://www.appledaily.com.tw/local/20220131/DUCANXBY3BHXPPXHKQAX6C7SL4/
# [1614] v https://www.appledaily.com.tw/local/20220131/DS2AAPPNIVDYBNK6UOF75YJCJ4/
# [1615] v https://www.appledaily.com.tw/local/20220131/EI2IQJPYHJF6VDKHSH2IWI6ZXY/
# [1616] v https://www.appledaily.com.tw/local/20220131/E6TO42AINJBNZITRM67BUR7M5A/
# [1617] v https://www.appledaily.com.tw/local/20220131/FUEGCA3TNBDVTBGPDAYO7VA7Z4/
# [1618] v https://www.appledaily.com.tw/local/20220131/JZJMXBR4YRD5DBB7QVB5FCLWSE/
# [1619] v https://www.appledaily.com.tw/local/20220131/ID7ZONOIUVAR7JPDVMHKK4FUKI/
# [1620] v https://www.appledaily.com.tw/local/20220131/KAC6JFT4IZHTJMZHQN2XD4G6AU/
# [1621] v https://www.appledaily.com.tw/local/20220131/GVJFN4FOUFGFJNIPQYAETM755Y/
# [1622] v https://www.appledaily.com.tw/local/20220131/JDEP2Z7BUVEOVFODIQC3QXWUQE/
# [1623] v https://www.appledaily.com.tw/local/20220131/A43ZRWYTSRE2VM3XEA2XPC72X4/
# [1624] v https://www.appledaily.com.tw/local/20220131/MDVB3RSCJVFRNIVPLXIEKUDAN4/
# [1625] v https://www.appledaily.com.tw/local/20220131/NI6ZK2NVMFA5PJMPQNAQZOS6JA/
# [1626] v https://www.appledaily.com.tw/local/20220131/NSGGCXKBDBEELJTFO3SEST7NMY/
# [1627] v https://www.appledaily.com.tw/local/20220131/QGRLGBLZRBDDVLU556VMLMJFDE/
# [1628] v https://www.appledaily.com.tw/local/20220131/S5PPA7MXVNAGTIS2ST4EHBUP4M/
# [1629] v https://www.appledaily.com.tw/local/20220131/SJGDMHVSCVCTPFVG7HCC54445U/
# [1630] v https://www.appledaily.com.tw/local/20220131/SSYRMG47UFBCNPYJKAY6WI7RGM/
# [1631] v https://www.appledaily.com.tw/local/20220131/LEKFRU22GJE67DRZMKLMDANJC4/
# [1632] v https://www.appledaily.com.tw/local/20220131/NGVBXRRIYNB3HNZ57ZP5PBG73A/
# [CDX錯誤] https://www.appledaily.com.tw/local/20220131/QWGQJ6VSOVEDHIRCKCT4VWAIWY/ → HTTPSConnectionPool(host='web.archive.org', port=443): Read timed out. (read timeout=20)
# [1633] x 失敗
# [1634] v https://www.appledaily.com.tw/local/20220131/S5UG47Y6BZBC3OZZDCML4AB2OE/
# [1635] v https://www.appledaily.com.tw/local/20220131/UF4IYIC7DFBZPGAQVOCEELK4ME/
# [1636] v https://www.appledaily.com.tw/local/20220131/UADYVRL4JZCYBPR7VWAHHTYJ2U/
# [1637] v https://www.appledaily.com.tw/local/20220131/VVBA2RIDVFE5ZCHMTCCCTOH7N4/
# [1638] v https://www.appledaily.com.tw/local/20220131/XM7DDZGU7RDSFNFJZGZLGG6F3A/
# [1639] v https://www.appledaily.com.tw/local/20220131/V5MRTCRYCVBWPHOYN7L5PDIGZE/
# [1640] v https://www.appledaily.com.tw/local/20220131/VWEZKWFCHJCUZASO6JQEUEREN4/
# [1641] v https://www.appledaily.com.tw/local/20220131/TB5IWAEAMJDE3FP2AMNZYBAF3Q/
# [1642] v https://www.appledaily.com.tw/local/20220131/YDMHW3JRFFDFTP4VI2GZVFCMSQ/
# v JSON 已輸出：wayback_threads.json
# v CSV 已輸出：wayback_threads.csv
# 結束時間： 2025-08-20 12:36:55
# 總耗時：1946.10 秒

# %%
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup
import time
from datetime import datetime

class WaybackScraper:
    def __init__(self):
        self.session = requests.Session()
        self.session.headers.update({
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
        })
    
    def get_latest_snapshot(self, url):
        params = {
            'url': url,
            'output': 'json',
            'filter': 'statuscode:200',
            'sort': 'reverse',
            'limit': 1
        }
        try:
            r = self.session.get("https://web.archive.org/cdx/search/cdx", params=params)
            r.raise_for_status()
            data = r.json()
            if len(data) > 1:
                row = data[1]
                return {
                    'timestamp': row[1],
                    'original_url': row[2],
                    'wayback_url': f"https://web.archive.org/web/{row[1]}/{row[2]}"
                }
        except Exception as e:
            print(f"[CDX錯誤] {url} → {e}")
        return None

    def scrape_webpage_content(self, wayback_url):
        try:
            resp = self.session.get(wayback_url, timeout=10)
            resp.raise_for_status()
            soup = BeautifulSoup(resp.content, 'html.parser')
            content = "\n".join([p.get_text().strip() for p in soup.find_all('p') if p.get_text().strip()])
            return content
        except Exception as e:
            print(f"[爬取錯誤] {wayback_url} → {e}")
            return None

    def format_timestamp(self, ts):
        try:
            return datetime.strptime(ts, "%Y%m%d%H%M%S").strftime("%Y-%m-%d %H:%M:%S")
        except:
            return ts

def main():
    # === 設定 ===
    csv_path = "only_in_b.csv"
    url_field = "uri"      #for wayback
    id_field  = "id"
    N_LIMIT = 1           # 如果只想抓前10筆，設10；全部抓改成 None

    # === 讀原始 CSV ===
    df = pd.read_csv(csv_path)
    if N_LIMIT:
        df = df.head(N_LIMIT)

    scraper = WaybackScraper()
    results = []

    for idx, row in df.iterrows():
        raw_url = row[url_field]
        print(f"[{idx+1}/{len(df)}] {raw_url}")
        snap = scraper.get_latest_snapshot(raw_url)
        if not snap:
            print("  x 沒找到快照\n")
            continue

        print("  → 快照 URL:", snap['wayback_url'])
        content = scraper.scrape_webpage_content(snap['wayback_url'])
        if content:
            result_row = {
                id_field: row[id_field],
                url_field: raw_url,
                "bodies": content,
                "timestamp": snap['timestamp'],
                "formatted_date": scraper.format_timestamp(snap['timestamp']),
                "wayback_url": snap['wayback_url']
            }
            results.append(result_row)
            print("  v 抓取成功\n")
        else:
            print("  x 內容讀取失敗\n")

        time.sleep(1)

    # === 匯出 CSV ===
        # --- 存檔 ---
    if results:
        # JSON 全量
        with open("wayback_latest_with_bodies.json", "w", encoding="utf-8") as f:
            json.dump(all_data, f, ensure_ascii=False, indent=2)
        print("[v] 已輸出 wayback_latest_with_bodies.json")
    if results:
        out_df = pd.DataFrame(results)
        out_df.to_csv("wayback_latest_with_bodies.csv", index=False, encoding="utf-8-sig")
        print(" v 已輸出 → wayback_latest_with_bodies.csv")
    else:
        print("全部失敗 ")

if __name__ == "__main__":
    main()
# Out:
# [1/1] https://www.appledaily.com.tw/local/20220101/23YFPLCSYZCZPANVI4E2LTW5L4/
#   → 快照 URL: https://web.archive.org/web/20220904084040/https://www.appledaily.com.tw/local/20220101/23YFPLCSYZCZPANVI4E2LTW5L4/
#   v 抓取成功
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 111
#     108         print("全部失敗 ")
#     110 if __name__ == "__main__":
# --> 111     main()
#
# Cell In[13], line 101, in main()
#      98 if results:
#      99     # JSON 全量
#     100     with open("wayback_latest_with_bodies.json", "w", encoding="utf-8") as f:
# --> 101         json.dump(all_data, f, ensure_ascii=False, indent=2)
#     102     print("[v] 已輸出 wayback_latest_with_bodies.json")
#     103 if results:
#
# NameError: name 'all_data' is not defined

# %%
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup
import time
from datetime import datetime

class WaybackScraper:
    def __init__(self):
        self.session = requests.Session()
        self.session.headers.update({
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
        })
    
    def get_latest_snapshot(self, url):
        params = {
            'url': url,
            'output': 'json',
            'filter': 'statuscode:200',
            'sort': 'reverse',
            'limit': 1
        }
        try:
            r = self.session.get("https://web.archive.org/cdx/search/cdx", params=params)
            r.raise_for_status()
            data = r.json()
            if len(data) > 1:
                row = data[1]
                return {
                    'timestamp': row[1],
                    'original_url': row[2],
                    'wayback_url': f"https://web.archive.org/web/{row[1]}/{row[2]}"
                }
        except Exception as e:
            print(f"[CDX錯誤] {url} → {e}")
        return None

    def scrape_webpage_content(self, wayback_url):
        try:
            resp = self.session.get(wayback_url, timeout=10)
            resp.raise_for_status()
            soup = BeautifulSoup(resp.content, 'html.parser')
            content = "\n".join([p.get_text().strip() for p in soup.find_all('p') if p.get_text().strip()])
            return content
        except Exception as e:
            print(f"[爬取錯誤] {wayback_url} → {e}")
            return None

    def format_timestamp(self, ts):
        try:
            return datetime.strptime(ts, "%Y%m%d%H%M%S").strftime("%Y-%m-%d %H:%M:%S")
        except:
            return ts

def main():
    csv_path = "only_in_b.csv"
    url_field = "uri"
    id_field  = "id"
    N_LIMIT = 50
    
    df = pd.read_csv(csv_path)
    if N_LIMIT:
        df = df.head(N_LIMIT)

    scraper = WaybackScraper()
    results = []

    for idx, row in df.iterrows():
        raw_url = row[url_field]
        print(f"[{idx+1}/{len(df)}] {raw_url}")
        snap = scraper.get_latest_snapshot(raw_url)
        if not snap:
            print("  x 沒找到快取\n")
            continue

        print("  → 快取 URL:", snap['wayback_url'])
        content = scraper.scrape_webpage_content(snap['wayback_url'])
        if content:
            result_row = {
                id_field: row[id_field],
                url_field: raw_url,
                "bodies": content,
                "timestamp": snap['timestamp'],
                "formatted_date": scraper.format_timestamp(snap['timestamp']),
                "wayback_url": snap['wayback_url']
            }
            results.append(result_row)
            print("  v 成功\n")
        else:
            print("  x 內容讀取失敗\n")

        time.sleep(1)

    if results:
        # --- JSON 全量輸出 ---
        with open("wayback_latest_with_bodies.json", "w", encoding="utf-8") as f:
            json.dump(results, f, ensure_ascii=False, indent=2)
        print("v 已輸出 wayback_latest_with_bodies.json")

        # --- CSV 摘要輸出 ---
        out_df = pd.DataFrame(results)
        out_df.to_csv("wayback_latest_with_bodies.csv", index=False, encoding="utf-8-sig")
        print("v 已輸出 wayback_latest_with_bodies.csv")
    else:
        print("全部失敗 :(")

if __name__ == "__main__":
    main()
# Out:
# [1/5] https://www.appledaily.com.tw/local/20220101/23YFPLCSYZCZPANVI4E2LTW5L4/
#   → 快照 URL: https://web.archive.org/web/20220904084040/https://www.appledaily.com.tw/local/20220101/23YFPLCSYZCZPANVI4E2LTW5L4/
#   v 成功
#
# [2/5] https://www.appledaily.com.tw/local/20220101/4C4Q3YRHTZGGBN2YAHLJH4CSQI/
#   → 快照 URL: https://web.archive.org/web/20220906014810/https://www.appledaily.com.tw/local/20220101/4C4Q3YRHTZGGBN2YAHLJH4CSQI/
#   v 成功
#
# [3/5] https://www.appledaily.com.tw/local/20220101/C4AZKGYVYZDVTPWZ7RPWARUHDY/
#   → 快照 URL: https://web.archive.org/web/20220903180022/https://www.appledaily.com.tw/local/20220101/C4AZKGYVYZDVTPWZ7RPWARUHDY/
#   v 成功
#
# [4/5] https://www.appledaily.com.tw/local/20220101/C5GNIZT4DNA4DAFUVA5NHKJYDI/
#   → 快照 URL: https://web.archive.org/web/20220908050404/https://www.appledaily.com.tw/local/20220101/C5GNIZT4DNA4DAFUVA5NHKJYDI/
#   v 成功
#
# [5/5] https://www.appledaily.com.tw/local/20220101/DUS6LUBV2FEHBHZ5R47BG6YCCY/
#   → 快照 URL: https://web.archive.org/web/20220903033433/https://www.appledaily.com.tw/local/20220101/DUS6LUBV2FEHBHZ5R47BG6YCCY/
#   v 成功
#
# v 已輸出 wayback_latest_with_bodies.json
# v 已輸出 wayback_latest_with_bodies.csv
